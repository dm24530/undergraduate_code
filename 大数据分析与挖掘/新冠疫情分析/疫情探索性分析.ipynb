# %% [markdown]
# # 1 数据可视化分析

# %%
import pandas as pd

# 读取数据
today_world = pd.read_csv("today_world_2021_01_07.csv")
# 查看世界各国实时数据 
today_world.head()
# Out:
#         id       lastUpdateTime  name  total_confirm  total_dead  total_heal  \
# 0  9577772  2021-01-07 08:23:02   突尼斯         149881        5004      111599
# 1  9507896  2021-01-07 08:23:02  塞尔维亚         352120        3444           0
# 2        0  2021-01-07 08:22:58    中国          97217        4795       91106
# 3        1  2021-01-07 08:23:02  日本本土         259495        3609      206883
# 4        2  2021-01-07 08:23:01    泰国           9331          66        4418
#
#    total_input  total_severe  total_suspect  today_confirm  today_dead  \
# 0          0.0             0              0         2820.0        70.0
# 1          0.0             0              0         2882.0         0.0
# 2       4359.0             0              0           90.0         1.0
# 3          0.0             0              0         6009.0         0.0
# 4          0.0             0              0          365.0         0.0
#
#    today_heal  today_input  today_severe  today_storeConfirm  today_suspect
# 0      1275.0          NaN           NaN                 NaN            NaN
# 1         0.0          NaN           NaN                 NaN            NaN
# 2        98.0         11.0           NaN                -9.0            NaN
# 3         0.0          NaN           NaN                 NaN            NaN
# 4         0.0          NaN           NaN                 NaN            NaN

# %%
#数据表各列名称为英文不便于观察，我们将列名修改为中文。首先，创建中英文对照的列名字典，使用rename()函数修改列名:
name_dict = {'date':'日期','name':'名称','id':'编号','lastUpdateTime':'更新时间',
             'today_confirm':'当日新增确诊','today_suspect':'当日新增疑似',
             'today_heal':'当日新增治愈','today_dead':'当日新增死亡',
             'today_severe':'当日新增重症','today_storeConfirm':'当日现存确诊',
             'total_confirm':'累计确诊','total_suspect':'累计疑似',
             'total_heal':'累计治愈','total_dead':'累计死亡','total_severe':'累计重症'}

# %%
# 更改列名
today_world.rename(columns=name_dict,inplace=True)    # inplace参数判断是否在原数据上进行修改

today_world.head(3)
# Out:
#         编号                 更新时间    名称    累计确诊  累计死亡    累计治愈  total_input  \
# 0  9577772  2021-01-07 08:23:02   突尼斯  149881  5004  111599          0.0
# 1  9507896  2021-01-07 08:23:02  塞尔维亚  352120  3444       0          0.0
# 2        0  2021-01-07 08:22:58    中国   97217  4795   91106       4359.0
#
#    累计重症  累计疑似  当日新增确诊  当日新增死亡  当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似
# 0     0     0  2820.0    70.0  1275.0          NaN     NaN     NaN     NaN
# 1     0     0  2882.0     0.0     0.0          NaN     NaN     NaN     NaN
# 2     0     0    90.0     1.0    98.0         11.0     NaN    -9.0     NaN

# %%
# 查看数据基本信息
today_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 16 columns):
# 编号             207 non-null object
# 更新时间           207 non-null object
# 名称             207 non-null object
# 累计确诊           207 non-null int64
# 累计死亡           207 non-null int64
# 累计治愈           207 non-null int64
# total_input    170 non-null float64
# 累计重症           207 non-null int64
# 累计疑似           207 non-null int64
# 当日新增确诊         160 non-null float64
# 当日新增死亡         160 non-null float64
# 当日新增治愈         160 non-null float64
# today_input    6 non-null float64
# 当日新增重症         13 non-null float64
# 当日现存确诊         1 non-null float64
# 当日新增疑似         13 non-null float64
# dtypes: float64(8), int64(5), object(3)
# memory usage: 26.0+ KB

# %%
#查看数据的统计信息可以使用describe()函数：
# 默认只计算数值型特征的统计信息
today_world.describe()
# Out:
#                累计确诊           累计死亡          累计治愈  total_input   累计重症   累计疑似  \
# count  2.070000e+02     207.000000  2.070000e+02   170.000000  207.0  207.0
# mean   4.223674e+05    9104.178744  2.975539e+05    25.641176    0.0    0.0
# std    1.807977e+06   33874.578993  1.267168e+06   334.320039    0.0    0.0
# min    1.000000e+00       0.000000  0.000000e+00     0.000000    0.0    0.0
# 25%    5.990000e+02      15.000000  2.125000e+02     0.000000    0.0    0.0
# 50%    2.304800e+04     306.000000  1.319900e+04     0.000000    0.0    0.0
# 75%    1.862125e+05    3137.000000  1.349215e+05     0.000000    0.0    0.0
# max    2.177736e+07  368792.000000  1.296847e+07  4359.000000    0.0    0.0
#
#               当日新增确诊       当日新增死亡         当日新增治愈  today_input  当日新增重症  当日现存确诊  \
# count     160.000000   160.000000     160.000000     6.000000    13.0     1.0
# mean     4374.393750    52.037500    1494.112500     1.833333     0.0    -9.0
# std     17024.219817   286.422169    9089.946317     4.490731     0.0     NaN
# min         0.000000     0.000000       0.000000     0.000000     0.0    -9.0
# 25%        39.750000     0.000000       0.000000     0.000000     0.0    -9.0
# 50%       410.000000     0.000000       0.000000     0.000000     0.0    -9.0
# 75%      2052.000000     3.250000      98.750000     0.000000     0.0    -9.0
# max    190798.000000  3172.000000  106256.000000    11.000000     0.0    -9.0
#
#        当日新增疑似
# count    13.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
#数据中当日新增确诊、疑似、治愈、死亡、重症和当日现存确诊中存在大量缺失值。为了便于观察，我们使用isnull()函数查看缺失值，并结合sum()函数计算缺失值比例。
# 计算缺失值比例
today_world_nan = today_world.isnull().sum()/len(today_world)

# 转变为百分数
today_world_nan.apply(lambda x: format(x, '.1%'))
# Out:
# 编号              0.0%
# 更新时间            0.0%
# 名称              0.0%
# 累计确诊            0.0%
# 累计死亡            0.0%
# 累计治愈            0.0%
# total_input    17.9%
# 累计重症            0.0%
# 累计疑似            0.0%
# 当日新增确诊         22.7%
# 当日新增死亡         22.7%
# 当日新增治愈         22.7%
# today_input    97.1%
# 当日新增重症         93.7%
# 当日现存确诊         99.5%
# 当日新增疑似         93.7%
# dtype: object

# %%
#当日现存确诊=累计确诊-累计治愈-累计死亡

# 缺失值处理
today_world['当日现存确诊'] = today_world['累计确诊']-today_world['累计治愈']-today_world['累计死亡']

# %%
#病死率=累计死亡÷累计确诊

# 计算病死率,且保留两位小数
today_world['病死率'] = (today_world['累计死亡']/today_world['累计确诊']).apply(lambda x: format(x, '.2f')) 

# 将病死率数据类型转换为float
today_world['病死率'] = today_world['病死率'].astype('float')

# 根据病死率降序排序
today_world.sort_values('病死率',ascending=False,inplace=True)

# 显示病死率前十国家
today_world.head(10)
# Out:
#          编号                 更新时间        名称     累计确诊    累计死亡     累计治愈  \
# 168   95200  2021-01-07 08:23:02        也门     2102     610     1403
# 144   95287  2020-06-15 14:48:56      圣马丁岛       77      15       61
# 16      828  2020-06-09 19:59:04     毛利亚尼亚       16       2        6
# 33    80902  2020-06-12 17:02:32     蒙特塞拉特       11       1       10
# 197   96745  2021-01-07 08:23:02       墨西哥  1466490  128822  1113137
# 125   95303  2020-06-15 13:51:31       圭亚那      159      12       99
# 151   89665  2020-06-15 13:49:44      瓜德罗普      171      14      157
# 28   875097  2020-06-12 17:06:26   美属维尔京群岛       72       6       46
# 176   95237  2020-06-15 14:48:06  特里尼达和多巴哥      123       8      109
# 99     8151  2020-06-15 13:01:51      巴巴多斯       96       7       83
#
#      total_input  累计重症  累计疑似   当日新增确诊  当日新增死亡  当日新增治愈  today_input  当日新增重症  \
# 168          0.0     0     0      1.0     0.0     2.0          NaN     NaN
# 144          NaN     0     0      NaN     NaN     NaN          NaN     NaN
# 16           NaN     0     0      NaN     NaN     NaN          NaN     NaN
# 33           NaN     0     0      NaN     NaN     NaN          NaN     NaN
# 197          0.0     0     0  11271.0     0.0     0.0          NaN     NaN
# 125          NaN     0     0      NaN     NaN     NaN          NaN     0.0
# 151          NaN     0     0      NaN     NaN     NaN          NaN     0.0
# 28           NaN     0     0      NaN     NaN     NaN          NaN     NaN
# 176          NaN     0     0      NaN     NaN     NaN          NaN     0.0
# 99           NaN     0     0      NaN     NaN     NaN          NaN     NaN
#
#      当日现存确诊  当日新增疑似   病死率
# 168      89     NaN  0.29
# 144       1     NaN  0.19
# 16        8     NaN  0.12
# 33        0     NaN  0.09
# 197  224531     NaN  0.09
# 125      48     0.0  0.08
# 151       0     0.0  0.08
# 28       20     NaN  0.08
# 176       6     0.0  0.07
# 99        6     NaN  0.07

# %%
# 将国家名称设为索引
today_world.set_index('名称',inplace=True)

today_world.head(3)
# Out:
#           编号                 更新时间  累计确诊  累计死亡  累计治愈  total_input  累计重症  累计疑似  \
# 名称
# 也门     95200  2021-01-07 08:23:02  2102   610  1403          0.0     0     0
# 圣马丁岛   95287  2020-06-15 14:48:56    77    15    61          NaN     0     0
# 毛利亚尼亚    828  2020-06-09 19:59:04    16     2     6          NaN     0     0
#
#        当日新增确诊  当日新增死亡  当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似   病死率
# 名称
# 也门        1.0     0.0     2.0          NaN     NaN      89     NaN  0.29
# 圣马丁岛      NaN     NaN     NaN          NaN     NaN       1     NaN  0.19
# 毛利亚尼亚     NaN     NaN     NaN          NaN     NaN       8     NaN  0.12

# %%
today_world.loc['中国']    #可以通过传入列表获取多个国家的数据
# Out:
# 编号                               0
# 更新时间           2021-01-07 08:22:58
# 累计确诊                         97217
# 累计死亡                          4795
# 累计治愈                         91106
# total_input                   4359
# 累计重症                             0
# 累计疑似                             0
# 当日新增确诊                          90
# 当日新增死亡                           1
# 当日新增治愈                          98
# today_input                     11
# 当日新增重症                         NaN
# 当日现存确诊                        1316
# 当日新增疑似                         NaN
# 病死率                           0.05
# Name: 中国, dtype: object

# %% [markdown]
# # 当前累计确诊人数top10国家

# %%
#使用sort_values()函数根据累计确诊人数进行排序，找到确诊人数前十国家的累计确诊、累计死亡、病死率三列数据
# 查看当前累计确诊人数前十国家
world_top10 = today_world.sort_values(['累计确诊'],ascending=False)[:10]

world_top10 = world_top10[['累计确诊','累计死亡','病死率']]

world_top10
# Out:
#          累计确诊    累计死亡   病死率
# 名称
# 美国   21777359  368792  0.02
# 印度   10374932  150114  0.01
# 巴西    7873830  198974  0.03
# 俄罗斯   3274615   59137  0.02
# 英国    2845236   77470  0.03
# 法国    2763116   66699  0.02
# 土耳其   2283931   22070  0.01
# 意大利   2201945   76877  0.03
# 西班牙   1982544   51430  0.03
# 德国    1841228   37314  0.02

# %%
# 导入matplotlib
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei']    #正常显示中文
plt.rcParams['figure.dpi'] = 120      #设置所有图片的清晰度

# %%
#绘制当前累计确诊人数top10国家的累计确诊、累计死亡和病死率的水平条形图。
# 绘制条形图
world_top10.sort_values('累计确诊').plot.barh(subplots=True,layout=(1,3),sharex=False,
                                             figsize=(7,4),legend=False,sharey=True)

plt.tight_layout()   #调整子图间距
plt.show()

# %% [markdown]
# # 2 全国各省实时数据探索性分析

# %%
# 读取数据
today_province = pd.read_csv("today_province_2021_01_07.csv")

# 创建中文列名字典
name_dict = {'date':'日期','name':'名称','id':'编号','lastUpdateTime':'更新时间',
             'today_confirm':'当日新增确诊','today_suspect':'当日新增疑似',
             'today_heal':'当日新增治愈','today_dead':'当日新增死亡',
             'today_severe':'当日新增重症','today_storeConfirm':'当日现存确诊',
             'total_confirm':'累计确诊','total_suspect':'累计疑似',
             'total_heal':'累计治愈','total_dead':'累计死亡','total_severe':'累计重症'}

# 更改列名
today_province.rename(columns=name_dict,inplace=True)    # inplace参数是否在原对象基础上进行修改

today_province.head(10)
# Out:
#        编号                 更新时间  名称   累计确诊  累计死亡   累计治愈  total_input  \
# 0  420000  2021-01-07 08:22:59  湖北  68149  4512  63637            0
# 1  810000  2021-01-07 09:08:03  香港   9074   154   8201            0
# 2  440000  2021-01-07 08:37:57  广东   2062     8   2018            0
# 3  310000  2021-01-07 15:48:25  上海   1543     7   1442            0
# 4  330000  2021-01-07 08:22:58  浙江   1306     1   1293            0
# 5  410000  2021-01-07 08:22:58  河南   1300    22   1271            0
# 6  430000  2021-01-07 08:22:59  湖南   1021     4   1016            0
# 7  110000  2021-01-07 08:22:58  北京    994     9    947            0
# 8  340000  2021-01-07 08:22:58  安徽    993     6    986            0
# 9  650000  2021-01-07 08:22:58  新疆    980     3    977            0
#
#    total_newConfirm  total_newDead  total_newHeal  累计重症  累计疑似  当日新增确诊  当日新增死亡  \
# 0               NaN            NaN            NaN     0     0       0       0
# 1               NaN            NaN            NaN     0     0      25       1
# 2               NaN            NaN            NaN     0     0       2       0
# 3               NaN            NaN            NaN     0     0       5       0
# 4               NaN            NaN            NaN     0     0       0       0
# 5               NaN            NaN            NaN     0     0       0       0
# 6               NaN            NaN            NaN     0     0       0       0
# 7             400.0            0.0          362.0     0     0       0       0
# 8               NaN            NaN            NaN     0     0       0       0
# 9               NaN            NaN            NaN     0     0       0       0
#
#    当日新增治愈  当日新增重症  当日现存确诊  当日新增疑似
# 0       0     NaN       0     NaN
# 1      74     NaN     -50     NaN
# 2       3     NaN      -1     NaN
# 3       5     NaN       0     NaN
# 4       0     NaN       0     NaN
# 5       0     NaN       0     NaN
# 6       0     NaN       0     NaN
# 7       2     NaN      -2     NaN
# 8       0     NaN       0     NaN
# 9       0     NaN       0     NaN

# %%
# 查看数据基本信息
today_province.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 18 columns):
# 编号                  34 non-null int64
# 更新时间                34 non-null object
# 名称                  34 non-null object
# 累计确诊                34 non-null int64
# 累计死亡                34 non-null int64
# 累计治愈                34 non-null int64
# total_input         34 non-null int64
# total_newConfirm    1 non-null float64
# total_newDead       1 non-null float64
# total_newHeal       1 non-null float64
# 累计重症                34 non-null int64
# 累计疑似                34 non-null int64
# 当日新增确诊              34 non-null int64
# 当日新增死亡              34 non-null int64
# 当日新增治愈              34 non-null int64
# 当日新增重症              0 non-null float64
# 当日现存确诊              34 non-null int64
# 当日新增疑似              0 non-null float64
# dtypes: float64(5), int64(11), object(2)
# memory usage: 4.9+ KB

# %%
# 查看数值型特征的统计量
today_province.describe()
# Out:
#                   编号          累计确诊         累计死亡          累计治愈  total_input  \
# count      34.000000     34.000000    34.000000     34.000000         34.0
# mean   422941.176471   2859.352941   141.029412   2679.617647          0.0
# std    195021.823359  11636.999920   772.771340  10859.669586          0.0
# min    110000.000000      1.000000     0.000000      1.000000          0.0
# 25%    312500.000000    226.250000     1.000000    217.500000          0.0
# 50%    425000.000000    555.500000     3.000000    539.000000          0.0
# 75%    537500.000000    989.750000     6.750000    970.000000          0.0
# max    820000.000000  68149.000000  4512.000000  63637.000000          0.0
#
#        total_newConfirm  total_newDead  total_newHeal  累计重症  累计疑似     当日新增确诊  \
# count               1.0            1.0            1.0  34.0  34.0  34.000000
# mean              400.0            0.0          362.0   0.0   0.0   2.676471
# std                 NaN            NaN            NaN   0.0   0.0   9.892515
# min               400.0            0.0          362.0   0.0   0.0   0.000000
# 25%               400.0            0.0          362.0   0.0   0.0   0.000000
# 50%               400.0            0.0          362.0   0.0   0.0   0.000000
# 75%               400.0            0.0          362.0   0.0   0.0   0.000000
# max               400.0            0.0          362.0   0.0   0.0  53.000000
#
#           当日新增死亡     当日新增治愈  当日新增重症     当日现存确诊  当日新增疑似
# count  34.000000  34.000000     0.0  34.000000     0.0
# mean    0.029412   3.058824     NaN  -0.411765     NaN
# std     0.171499  12.696793     NaN  12.794690     NaN
# min     0.000000   0.000000     NaN -50.000000     NaN
# 25%     0.000000   0.000000     NaN   0.000000     NaN
# 50%     0.000000   0.000000     NaN   0.000000     NaN
# 75%     0.000000   1.000000     NaN   0.000000     NaN
# max     1.000000  74.000000     NaN  53.000000     NaN

# %%
#发现，累计疑似、累计重症、当日新增疑似和当日新增重症的数据全部为0，因此我们便不予考虑。
# 计算各省当日现存确诊人数
today_province['当日现存确诊'] = today_province['累计确诊']-today_province['累计治愈']-today_province['累计死亡']

# 将各省名称设置为索引
today_province.set_index('名称',inplace=True)

today_province.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 湖北 to 西藏
# Data columns (total 17 columns):
# 编号                  34 non-null int64
# 更新时间                34 non-null object
# 累计确诊                34 non-null int64
# 累计死亡                34 non-null int64
# 累计治愈                34 non-null int64
# total_input         34 non-null int64
# total_newConfirm    1 non-null float64
# total_newDead       1 non-null float64
# total_newHeal       1 non-null float64
# 累计重症                34 non-null int64
# 累计疑似                34 non-null int64
# 当日新增确诊              34 non-null int64
# 当日新增死亡              34 non-null int64
# 当日新增治愈              34 non-null int64
# 当日新增重症              0 non-null float64
# 当日现存确诊              34 non-null int64
# 当日新增疑似              0 non-null float64
# dtypes: float64(5), int64(11), object(1)
# memory usage: 4.8+ KB

# %% [markdown]
# # 全国新增确诊top10地区

# %%
# 查看全国新增确诊top10的地区
new_top6 = today_province['当日新增确诊'].sort_values(ascending=False)[:10]

new_top6
# Out:
# 名称
# 河北     53
# 香港     25
# 上海      5
# 广东      2
# 陕西      2
# 台湾      2
# 黑龙江     1
# 辽宁      1
# 西藏      0
# 山东      0
# Name: 当日新增确诊, dtype: int64

# %%
# 绘制条形图和饼图
fig,ax = plt.subplots(1,2,figsize=(10,5))

new_top6.sort_values(ascending=True).plot.barh(fontsize=10,ax=ax[0])
new_top6.plot.pie(autopct='%.1f%%',fontsize=10,ax=ax[1])

plt.ylabel('')
plt.title('全国新增确诊top10地区',size=15)
plt.show()

# %% [markdown]
# # 全国现存确诊人数top10的地区

# %%
# 查看全国现存确诊人数top10的省市
store_top10 = today_province['当日现存确诊'].sort_values(ascending=False)[:10]

store_top10
# Out:
# 名称
# 香港    719
# 台湾    112
# 上海     94
# 河北     92
# 辽宁     68
# 北京     38
# 广东     36
# 四川     26
# 陕西     25
# 福建     23
# Name: 当日现存确诊, dtype: int64

# %%
# 绘制条形图

store_top10.sort_values(ascending=True).plot.barh(fontsize=10)

plt.title('全国现存确诊top10地区',size=15)
plt.show()

# %% [markdown]
# # 全国历史数据探索性分析

# %%
# 读取数据
alltime_china = pd.read_csv("alltime_China_2021_01_07.csv")

# 创建中文列名字典
name_dict = {'date':'日期','name':'名称','id':'编号','lastUpdateTime':'更新时间',
             'today_confirm':'当日新增确诊','today_suspect':'当日新增疑似',
             'today_heal':'当日新增治愈','today_dead':'当日新增死亡',
             'today_severe':'当日新增重症','today_storeConfirm':'当日现存确诊',
             'total_confirm':'累计确诊','total_suspect':'累计疑似',
             'total_heal':'累计治愈','total_dead':'累计死亡','total_severe':'累计重症'}

# 更改列名
alltime_china.rename(columns=name_dict,inplace=True)

alltime_china.head()
# Out:
#            日期  更新时间  累计确诊  累计死亡  累计治愈  total_input  累计重症  total_storeConfirm  \
# 0  2020-01-13   NaN    41     1     0            0   NaN                   0
# 1  2020-01-14   NaN    41     1     0            0   NaN                   0
# 2  2020-01-15   NaN    41     2     5            0   NaN                   0
# 3  2020-01-16   NaN    45     2     8            0   NaN                   0
# 4  2020-01-17   NaN    62     2    12            0   NaN                   0
#
#    累计疑似  当日新增确诊  当日新增死亡  当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似
# 0     0       0       0       0            0     NaN       0       0
# 1     0       0       0       0            0     NaN       0       0
# 2     0       0       0       0            0     NaN       0       0
# 3     0       0       0       0            0     NaN       0       0
# 4     0       0       0       0            0     NaN       0       0

# %%
alltime_china.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 16 columns):
# 日期                    360 non-null object
# 更新时间                  0 non-null float64
# 累计确诊                  360 non-null int64
# 累计死亡                  360 non-null int64
# 累计治愈                  360 non-null int64
# total_input           360 non-null int64
# 累计重症                  0 non-null float64
# total_storeConfirm    360 non-null int64
# 累计疑似                  360 non-null int64
# 当日新增确诊                360 non-null int64
# 当日新增死亡                360 non-null int64
# 当日新增治愈                360 non-null int64
# today_input           360 non-null int64
# 当日新增重症                0 non-null float64
# 当日现存确诊                360 non-null int64
# 当日新增疑似                360 non-null int64
# dtypes: float64(3), int64(12), object(1)
# memory usage: 45.1+ KB

# %%
# 查看数据的统计信息
alltime_china.describe()
# Out:
#        更新时间          累计确诊         累计死亡          累计治愈  total_input  累计重症  \
# count   0.0    360.000000   360.000000    360.000000   360.000000   0.0
# mean    NaN  81207.305556  4021.394444  71913.397222  2028.011111   NaN
# std     NaN  21773.479561  1334.458387  26190.333908  1306.882054   NaN
# min     NaN     41.000000     1.000000      0.000000     0.000000   NaN
# 25%     NaN  83572.000000  3350.500000  77880.750000  1353.500000   NaN
# 50%     NaN  85504.500000  4648.000000  80303.500000  1967.500000   NaN
# 75%     NaN  91258.500000  4746.000000  86112.000000  2975.750000   NaN
# max     NaN  97217.000000  4795.000000  91106.000000  4359.000000   NaN
#
#        total_storeConfirm   累计疑似        当日新增确诊  当日新增死亡  当日新增治愈  today_input  \
# count          360.000000  360.0    360.000000   360.0   360.0   360.000000
# mean          5268.105556    0.0    272.130556     0.0     0.0    12.058333
# std          12299.862018    0.0   1023.431024     0.0     0.0    14.121417
# min              0.000000    0.0      0.000000     0.0     0.0     0.000000
# 25%            439.000000    0.0     20.000000     0.0     0.0     3.000000
# 50%            834.000000    0.0     40.500000     0.0     0.0     9.000000
# 75%           2005.750000    0.0    104.500000     0.0     0.0    16.000000
# max          58097.000000    0.0  15153.000000     0.0     0.0    98.000000
#
#        当日新增重症  当日现存确诊       当日新增疑似
# count     0.0   360.0   360.000000
# mean      NaN     0.0   273.308333
# std       NaN     0.0   947.357255
# min       NaN     0.0     0.000000
# 25%       NaN     0.0     0.000000
# 50%       NaN     0.0     1.000000
# 75%       NaN     0.0     5.000000
# max       NaN     0.0  5328.000000

# %%
# 缺失值处理

# 计算当日现存确诊人数
alltime_china['当日现存确诊'] = alltime_china['累计确诊']-alltime_china['累计治愈']-alltime_china['累计死亡']

# 删除更新时间一列
alltime_china.drop(['更新时间','当日新增重症'],axis=1,inplace=True)

alltime_china.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 14 columns):
# 日期                    360 non-null object
# 累计确诊                  360 non-null int64
# 累计死亡                  360 non-null int64
# 累计治愈                  360 non-null int64
# total_input           360 non-null int64
# 累计重症                  0 non-null float64
# total_storeConfirm    360 non-null int64
# 累计疑似                  360 non-null int64
# 当日新增确诊                360 non-null int64
# 当日新增死亡                360 non-null int64
# 当日新增治愈                360 non-null int64
# today_input           360 non-null int64
# 当日现存确诊                360 non-null int64
# 当日新增疑似                360 non-null int64
# dtypes: float64(1), int64(12), object(1)
# memory usage: 39.5+ KB

# %%
# 将日期改成datetime格式
alltime_china['日期'] = pd.to_datetime(alltime_china['日期'])

# 设置日期为索引
alltime_china.set_index('日期',inplace=True)     # 也可使用pd.read_csv("./input/alltime_China_2020_03_27.csv",parse_dates=['date'],index_col='date')

alltime_china.index
# Out:
# DatetimeIndex(['2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22',
#                ...
#                '2020-12-28', '2020-12-29', '2020-12-30', '2020-12-31',
#                '2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06'],
#               dtype='datetime64[ns]', name='日期', length=360, freq=None)

# %%
#数据清洗之后，我们将绘制折线图查看新冠肺炎数据的变化趋势：
# 时间序列数据绘制折线图
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import datetime

fig, ax = plt.subplots(figsize=(8,4))

alltime_china.plot(marker='o',ms=2,lw=1,ax=ax)

ax.xaxis.set_major_locator(dates.MonthLocator())    #设置间距
ax.xaxis.set_major_formatter(dates.DateFormatter('%b'))    #设置日期格式

fig.autofmt_xdate()    #自动调整日期倾斜

# 图例位置调整
plt.legend(bbox_to_anchor = [1,1])

plt.title('全国新冠肺炎数据折线图',size=15)
plt.ylabel('人数')
plt.grid(axis='y')
plt.box(False)
plt.show()

# %%
# 时间序列数据绘制折线图
fig, ax = plt.subplots(figsize=(8,4))

alltime_china['当日新增确诊'].plot(ax=ax, style='-',lw=1,color='c',marker='o',ms=3)

ax.xaxis.set_major_locator(dates.MonthLocator())    #设置间距
ax.xaxis.set_major_formatter(dates.DateFormatter('%b'))    #设置日期格式

fig.autofmt_xdate()    #自动调整日期倾斜

plt.title('全国新冠肺炎新增确诊病例折线图',size=15)
plt.ylabel('人数')
plt.grid(axis='y')
plt.box(False)
plt.show()

# %% [markdown]
# # 3  世界各国历史数据探索性分析

# %%
# 读取数据
alltime_world = pd.read_csv("alltime_world_2021_01_07.csv")

# 创建中文列名字典
name_dict = {'date':'日期','name':'名称','id':'编号','lastUpdateTime':'更新时间',
             'today_confirm':'当日新增确诊','today_suspect':'当日新增疑似',
             'today_heal':'当日新增治愈','today_dead':'当日新增死亡',
             'today_severe':'当日新增重症','today_storeConfirm':'当日现存确诊',
             'total_confirm':'累计确诊','total_suspect':'累计疑似',
             'total_heal':'累计治愈','total_dead':'累计死亡','total_severe':'累计重症'}

# 更改列名
alltime_world.rename(columns=name_dict,inplace=True)

alltime_world.head()
# Out:
#            日期  累计确诊  累计死亡  累计治愈  total_input  累计重症  累计疑似  当日新增确诊  当日新增死亡  \
# 0  2020-03-03     1     0     0            0     0     0       1       0
# 1  2020-03-08     2     0     0            0     0     0       1       0
# 2  2020-03-09     5     0     0            0     0     0       3       0
# 3  2020-03-11     7     0     0            0     0     0       2       0
# 4  2020-03-12    13     0     0            0     0     0       6       0
#
#    当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似   名称
# 0       0          NaN     NaN     NaN     0.0  突尼斯
# 1       0          0.0     0.0     NaN     0.0  突尼斯
# 2       0          0.0     0.0     NaN     0.0  突尼斯
# 3       0          0.0     0.0     NaN     0.0  突尼斯
# 4       0          0.0     0.0     NaN     0.0  突尼斯

# %%
# 查看数据基本信息
alltime_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46472 entries, 0 to 46471
# Data columns (total 15 columns):
# 日期             46472 non-null object
# 累计确诊           46472 non-null int64
# 累计死亡           46472 non-null int64
# 累计治愈           46472 non-null int64
# total_input    46472 non-null int64
# 累计重症           46472 non-null int64
# 累计疑似           46472 non-null int64
# 当日新增确诊         46472 non-null int64
# 当日新增死亡         46472 non-null int64
# 当日新增治愈         46472 non-null int64
# today_input    46276 non-null float64
# 当日新增重症         12509 non-null float64
# 当日现存确诊         0 non-null float64
# 当日新增疑似         12909 non-null float64
# 名称             46472 non-null object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 5.3+ MB

# %%
alltime_world.describe()
# Out:
#                累计确诊           累计死亡          累计治愈   total_input          累计重症  \
# count  4.647200e+04   46472.000000  4.647200e+04  46472.000000  46472.000000
# mean   1.739780e+05    4996.385221  1.193152e+05     15.413905      2.380810
# std    8.830918e+05   20635.575098  6.413369e+05    209.917572    103.685836
# min    0.000000e+00       0.000000  0.000000e+00      0.000000      0.000000
# 25%    1.289000e+03      24.000000  5.150000e+02      0.000000      0.000000
# 50%    8.887000e+03     157.000000  4.943000e+03      0.000000      0.000000
# 75%    7.170250e+04    1408.000000  4.035375e+04      0.000000      0.000000
# max    2.185762e+07  369990.000000  1.302414e+07   4359.000000   7365.000000
#
#                累计疑似         当日新增确诊        当日新增死亡        当日新增治愈   today_input  \
# count  46472.000000   46472.000000  46472.000000  4.647200e+04  46276.000000
# mean       5.893527    1884.868394     40.650263  1.328248e+03      0.094196
# std      321.784752   10611.751102    182.648132  9.299092e+03      3.650378
# min        0.000000  -65415.000000  -6464.000000 -3.444680e+05    -19.000000
# 25%        0.000000       5.000000      0.000000  0.000000e+00      0.000000
# 50%        0.000000      78.000000      1.000000  2.300000e+01      0.000000
# 75%        0.000000     637.000000     11.000000  3.400000e+02      0.000000
# max    28942.000000  880962.000000   7867.000000  1.151187e+06    723.000000
#
#              当日新增重症  当日现存确诊        当日新增疑似
# count  12509.000000     0.0  12909.000000
# mean      -0.581341     NaN      3.528314
# std       12.372097     NaN     95.676476
# min     -464.000000     NaN      0.000000
# 25%        0.000000     NaN      0.000000
# 50%        0.000000     NaN      0.000000
# 75%        0.000000     NaN      0.000000
# max        0.000000     NaN   4008.000000

# %%
# 将日期一列数据类型变为datetime
alltime_world['日期'] = pd.to_datetime(alltime_world['日期'])

# 计算当日现存确诊
alltime_world['当日现存确诊'] = alltime_world['累计确诊']-alltime_world['累计治愈']-alltime_world['累计死亡']

alltime_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46472 entries, 0 to 46471
# Data columns (total 15 columns):
# 日期             46472 non-null datetime64[ns]
# 累计确诊           46472 non-null int64
# 累计死亡           46472 non-null int64
# 累计治愈           46472 non-null int64
# total_input    46472 non-null int64
# 累计重症           46472 non-null int64
# 累计疑似           46472 non-null int64
# 当日新增确诊         46472 non-null int64
# 当日新增死亡         46472 non-null int64
# 当日新增治愈         46472 non-null int64
# today_input    46276 non-null float64
# 当日新增重症         12509 non-null float64
# 当日现存确诊         46472 non-null int64
# 当日新增疑似         12909 non-null float64
# 名称             46472 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(10), object(1)
# memory usage: 5.3+ MB

# %%
# 查看唯一值,可使用len()查看个数
alltime_world['名称'].unique()
# Out:
# array(['突尼斯', '塞尔维亚', '中国', '日本本土', '泰国', '新加坡', '韩国', '澳大利亚', '德国', '美国',
#        '马来西亚', '越南', '圣巴泰勒米', '肯尼亚', '伊朗', '以色列', '毛利亚尼亚', '黎巴嫩', '克罗地亚',
#        '奥地利', '瑞士', '希腊', '毛里求斯', '爱沙尼亚', '北马其顿', '白俄罗斯', '立陶宛', '阿塞拜疆',
#        '美属维尔京群岛', '蒙古', '乌克兰', '波兰', '波黑', '蒙特塞拉特', '南非', '布隆迪', '南苏丹',
#        '马耳他', '摩尔多瓦', '保加利亚', '孟加拉', '阿尔巴尼亚', '巴勒斯坦', '科摩罗', '阿富汗',
#        '沙特阿拉伯', '新西兰', '塔吉克斯坦', '泽西岛', '叙利亚', '巴拿马', '古巴', '尼日利亚', '摩洛哥',
#        '塞内加尔', '老挝', '巴哈马', '马约特岛', '斯洛文尼亚', '卢森堡', '爱尔兰', '厄瓜多尔', '捷克',
#        '匈牙利', '法属圭亚那', '多哥共和国', '哥斯达黎加', '文莱', '法罗群岛', '马提尼克岛', '荷兰',
#        '巴西', '洪都拉斯', '乌拉圭', '秘鲁', '智利', '格陵兰', '圣巴托洛谬岛', '马尔代夫', '委内瑞拉',
#        '毛里塔尼亚', '纳米比亚', '法属留尼汪岛', '波多黎各', '加纳', '赤道几内亚', '几内亚', '卢旺达',
#        '格林纳达', '斯威士兰', '坦桑尼亚', '贝宁', '刚果（金）', '中非共和国', '利比里亚', '索马里',
#        '塞拉利昂', '乍得', '赞比亚', '巴巴多斯', '马里', '阿根廷', '法属波利尼西亚', '巴林', '莫桑比克',
#        '喀麦隆', '乌干达', '厄立特里亚', '刚果（布）', '津巴布韦', '丹麦', '阿鲁巴', '斐济', '伯利兹',
#        '缅甸', '塞浦路斯', '关岛', '科索沃', '圣皮埃尔岛和密克隆岛', '吉尔吉斯斯坦', '博茨瓦纳', '尼日尔',
#        '苏里南', '佛得角', '萨尔瓦多', '圭亚那', '尼加拉瓜', '冈比亚', '东帝汶', '巴基斯坦', '埃及',
#        '科威特', '斯洛伐克', '直布罗陀', '摩纳哥', '巴拉圭', '荷属安的列斯', '多米尼克', '乌兹别克斯坦',
#        '黑山', '危地马拉', '加蓬', '苏丹', '利比亚', '圣马丁岛', '土耳其', '巴布亚新几内亚', '多米尼加',
#        '约旦', '亚美尼亚', '圣基茨和尼维斯', '瓜德罗普', '安提瓜和巴布达', '玻利维亚', '哥伦比亚',
#        '圣文森特和格林纳丁斯', '圣卢西亚', '法国', '阿联酋', '加拿大', '印度', '英国', '意大利', '俄罗斯',
#        '菲律宾', '芬兰', '尼泊尔', '葡萄牙', '也门', '塞舌尔', '西班牙', '斯里兰卡', '阿尔及利亚',
#        '柬埔寨', '海地', '瑞典', '特里尼达和多巴哥', '吉布提', '圣多美与普林西比', '布基纳法索', '比利时',
#        '伊拉克', '马拉维', '冰岛', '几内亚比绍', '拉脱维亚', '不丹', '挪威', '印度尼西亚', '安哥拉',
#        '开曼群岛', '埃塞俄比亚', '梵蒂冈', '科特迪瓦', '卡塔尔', '莱索托', '格鲁吉亚', '墨西哥',
#        '圣马力诺', '哈萨克斯坦', '安道尔', '牙买加', '格恩西岛', '罗马尼亚', '阿曼', '列支敦士登',
#        '马达加斯加'], dtype=object)

# %%
# 统计每天有多少国家出现疫情
alltime_world['日期'].value_counts().head(20)
# Out:
# 2020-05-24    207
# 2020-05-27    207
# 2020-06-08    207
# 2020-06-11    206
# 2020-05-30    206
# 2020-05-31    206
# 2020-06-05    206
# 2020-06-10    206
# 2020-06-01    206
# 2020-05-26    205
# 2020-05-14    205
# 2020-05-12    205
# 2020-05-19    205
# 2020-06-03    205
# 2020-06-04    204
# 2020-05-20    204
# 2020-06-06    204
# 2020-05-25    204
# 2020-05-18    203
# 2020-05-11    202
# Name: 日期, dtype: int64

# %%
# 设置日期索引
alltime_world.set_index('日期',inplace=True)

# %% [markdown]
# # 选取多国数据

# %%
# groupby创建层次化索引
data = alltime_world.groupby(['日期','名称']).mean()

data.head(30)
# Out:
#                   累计确诊  累计死亡  累计治愈  total_input  累计重症   累计疑似  当日新增确诊  当日新增死亡  \
# 日期         名称
# 2020-01-20 韩国        1     0     0            0     0      0       1       0
# 2020-01-21 韩国        1     0     0            0     0      0       0       0
# 2020-01-22 韩国        1     0     0            0     0      0       0       0
# 2020-01-23 韩国        1     0     0            0     0      0       0       0
# 2020-01-24 韩国        2     0     0            0     0      0       1       0
# 2020-01-25 韩国        2     0     0            0     0      0       0       0
# 2020-01-26 韩国        3     0     0            0     0      0       1       0
# 2020-01-27 韩国        4     0     0            0     0      0       1       0
# 2020-01-28 日本本土      4     0     0            0     0      0       4       0
#            韩国        4     0     0            0     0      0       0       0
# 2020-01-29 韩国        4     0     0            0     0      0       0       0
# 2020-01-30 日本本土      6     0     0            0     0      0       2       0
#            韩国        6     0     0            0     0      0       2       0
# 2020-01-31 意大利       2     0     0            0     0      0       2       0
#            日本本土     15     0     0            0     0      0       9       0
#            韩国       11     0     0            0     0      0       5       0
# 2020-02-01 意大利       2     0     0            0     0      0       0       0
#            日本本土     20     0     0            0     0      0       5       0
#            韩国       12     0     0            0     0      0       1       0
# 2020-02-02 意大利       2     0     0            0     0      0       0       0
#            韩国       15     0     0            0     0      0       3       0
# 2020-02-03 意大利       2     0     0            0     0      0       0       0
#            韩国       15     0     0            0     0      0       0       0
# 2020-02-04 意大利       2     0     0            0     0      0       0       0
#            韩国       16     0     0            0     0      0       1       0
# 2020-02-05 中国    24433   493   962            0     0  23260   24433     493
#            意大利       2     0     0            0     0      0       0       0
#            日本本土     30     0     0            0     0      0      10       0
#            韩国       19     0     1            0     0      0       3       0
# 2020-02-06 中国    31161   637  1540            0     0  26359    6728     144
#
#                  当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似
# 日期         名称
# 2020-01-20 韩国         0          NaN     NaN       1     0.0
# 2020-01-21 韩国         0          0.0     NaN       1     0.0
# 2020-01-22 韩国         0          0.0     NaN       1     0.0
# 2020-01-23 韩国         0          0.0     NaN       1     0.0
# 2020-01-24 韩国         0          0.0     NaN       2     0.0
# 2020-01-25 韩国         0          0.0     NaN       2     0.0
# 2020-01-26 韩国         0          0.0     NaN       3     0.0
# 2020-01-27 韩国         0          0.0     NaN       4     0.0
# 2020-01-28 日本本土       0          NaN     NaN       4     0.0
#            韩国         0          0.0     NaN       4     0.0
# 2020-01-29 韩国         0          0.0     NaN       4     0.0
# 2020-01-30 日本本土       0          0.0     NaN       6     0.0
#            韩国         0          0.0     NaN       6     0.0
# 2020-01-31 意大利        0          NaN     NaN       2     0.0
#            日本本土       0          0.0     NaN      15     0.0
#            韩国         0          0.0     NaN      11     0.0
# 2020-02-01 意大利        0          0.0     NaN       2     0.0
#            日本本土       0          0.0     NaN      20     0.0
#            韩国         0          0.0     NaN      12     0.0
# 2020-02-02 意大利        0          0.0     NaN       2     0.0
#            韩国         0          0.0     NaN      15     0.0
# 2020-02-03 意大利        0          0.0     NaN       2     0.0
#            韩国         0          0.0     NaN      15     0.0
# 2020-02-04 意大利        0          0.0     NaN       2     0.0
#            韩国         0          0.0     NaN      16     0.0
# 2020-02-05 中国       962          NaN     NaN   22978  3971.0
#            意大利        0          0.0     NaN       2     0.0
#            日本本土       0          0.0     NaN      30     0.0
#            韩国         1          0.0     NaN      18     0.0
# 2020-02-06 中国       578          0.0     NaN   28984  3230.0

# %%
# 提取部分数据
data_part = data.loc(axis=0)[:,['中国','日本','韩国','美国','意大利','英国','西班牙','德国']]

data_part.head()
# Out:
#                累计确诊  累计死亡  累计治愈  total_input  累计重症  累计疑似  当日新增确诊  当日新增死亡  \
# 日期         名称
# 2020-01-20 韩国     1     0     0            0     0     0       1       0
# 2020-01-21 韩国     1     0     0            0     0     0       0       0
# 2020-01-22 韩国     1     0     0            0     0     0       0       0
# 2020-01-23 韩国     1     0     0            0     0     0       0       0
# 2020-01-24 韩国     2     0     0            0     0     0       1       0
#
#                当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似
# 日期         名称
# 2020-01-20 韩国       0          NaN     NaN       1     0.0
# 2020-01-21 韩国       0          0.0     NaN       1     0.0
# 2020-01-22 韩国       0          0.0     NaN       1     0.0
# 2020-01-23 韩国       0          0.0     NaN       1     0.0
# 2020-01-24 韩国       0          0.0     NaN       2     0.0

# %%
# groupby创建层次化索引
data = alltime_world.groupby(['日期','名称']).mean()

data.head()
# Out:
#                累计确诊  累计死亡  累计治愈  total_input  累计重症  累计疑似  当日新增确诊  当日新增死亡  \
# 日期         名称
# 2020-01-20 韩国     1     0     0            0     0     0       1       0
# 2020-01-21 韩国     1     0     0            0     0     0       0       0
# 2020-01-22 韩国     1     0     0            0     0     0       0       0
# 2020-01-23 韩国     1     0     0            0     0     0       0       0
# 2020-01-24 韩国     2     0     0            0     0     0       1       0
#
#                当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似
# 日期         名称
# 2020-01-20 韩国       0          NaN     NaN       1     0.0
# 2020-01-21 韩国       0          0.0     NaN       1     0.0
# 2020-01-22 韩国       0          0.0     NaN       1     0.0
# 2020-01-23 韩国       0          0.0     NaN       1     0.0
# 2020-01-24 韩国       0          0.0     NaN       2     0.0

# %%
# 提取部分数据
data_part = data.loc(axis=0)[:,['中国','日本','韩国','美国','意大利','英国','西班牙','德国']]

data_part.head()
# Out:
#                累计确诊  累计死亡  累计治愈  total_input  累计重症  累计疑似  当日新增确诊  当日新增死亡  \
# 日期         名称
# 2020-01-20 韩国     1     0     0            0     0     0       1       0
# 2020-01-21 韩国     1     0     0            0     0     0       0       0
# 2020-01-22 韩国     1     0     0            0     0     0       0       0
# 2020-01-23 韩国     1     0     0            0     0     0       0       0
# 2020-01-24 韩国     2     0     0            0     0     0       1       0
#
#                当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似
# 日期         名称
# 2020-01-20 韩国       0          NaN     NaN       1     0.0
# 2020-01-21 韩国       0          0.0     NaN       1     0.0
# 2020-01-22 韩国       0          0.0     NaN       1     0.0
# 2020-01-23 韩国       0          0.0     NaN       1     0.0
# 2020-01-24 韩国       0          0.0     NaN       2     0.0

# %%
# 将层级索引还原
data_part.reset_index('名称',inplace=True)

data_part.head()
# Out:
#             名称  累计确诊  累计死亡  累计治愈  total_input  累计重症  累计疑似  当日新增确诊  当日新增死亡  \
# 日期
# 2020-01-20  韩国     1     0     0            0     0     0       1       0
# 2020-01-21  韩国     1     0     0            0     0     0       0       0
# 2020-01-22  韩国     1     0     0            0     0     0       0       0
# 2020-01-23  韩国     1     0     0            0     0     0       0       0
# 2020-01-24  韩国     2     0     0            0     0     0       1       0
#
#             当日新增治愈  today_input  当日新增重症  当日现存确诊  当日新增疑似
# 日期
# 2020-01-20       0          NaN     NaN       1     0.0
# 2020-01-21       0          0.0     NaN       1     0.0
# 2020-01-22       0          0.0     NaN       1     0.0
# 2020-01-23       0          0.0     NaN       1     0.0
# 2020-01-24       0          0.0     NaN       2     0.0

# %% [markdown]
# # 绘制多个国家的累计确诊人数折线图

# %%
# 绘制多个国家的累计确诊人数折线图
fig, ax = plt.subplots(figsize=(8,4))

data_part['2021-01':].groupby('名称')['累计确诊'].plot(legend=True,marker='o',ms=3,lw=1)

ax.xaxis.set_major_locator(dates.MonthLocator())    #设置间距
ax.xaxis.set_major_formatter(dates.DateFormatter('%b'))    #设置日期格式

fig.autofmt_xdate()    #自动调整日期倾斜

plt.title('各国新冠肺炎累计确诊病例折线图',size=15)
plt.ylabel('人数')
plt.grid(axis='y')
plt.box(False)
plt.legend(bbox_to_anchor = [1,1])
plt.show()

# %%
# 绘制各国新增确诊人数折线图
fig, ax = plt.subplots(figsize=(8,4))

data_part['2021-01':'2021-01-07'].groupby('名称')['当日新增确诊'].plot(legend=True,marker='o',ms=3,lw=1)

ax.xaxis.set_major_locator(dates.MonthLocator())    #设置间距
ax.xaxis.set_major_formatter(dates.DateFormatter('%b'))    #设置日期格式

fig.autofmt_xdate()    #自动调整日期倾斜

plt.title('各国新冠肺炎新增确诊病例折线图',size=15)
plt.ylabel('人数')
plt.grid(axis='y')
plt.box(False)
plt.legend(bbox_to_anchor = [1,1])
plt.show()

# %%
japan = alltime_world[alltime_world['名称']=='意大利']

fig, ax = plt.subplots(figsize=(8,4))

japan['累计确诊'].plot(ax=ax, fontsize=10, style='-',lw=1,color='c',marker='o',ms=3,legend=True)
ax.set_ylabel('人数', fontsize=10)

ax1 = ax.twinx()
ax1.bar(japan.index, japan['当日新增确诊'])
ax1.xaxis.set_major_locator(dates.DayLocator(interval = 5))
ax1.xaxis.set_major_formatter(dates.DateFormatter('%b %d'))
ax1.legend(['当日新增确诊'],loc='upper left',bbox_to_anchor=(0.001, 0.9))
plt.grid(axis='y')
plt.box(False)
plt.title('意大利新冠肺炎疫情折线图',size=15)

plt.show()
