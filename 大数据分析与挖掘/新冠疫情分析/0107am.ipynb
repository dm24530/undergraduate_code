# %% [markdown]
# # 选取数据源

# %%
# 首先导入使用的包，使用request进行网页请求，使用pandas保存数据。
import requests
import pandas as pd
import time
pd.set_option('max_rows',500)    #修改显示的最大行数，如果超过设置的行和列就显示省略号，

# 设置请求头，伪装为浏览器
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36'
}

# 发起请求，将找到的第一个数据源作为请求目标。
url = 'https://c.m.163.com/ug/api/wuhan/app/data/list-total'   # 定义要访问的地址
r = requests.get(url, headers=headers)  # 使用requests发起请求
print(r.status_code)  # 查看请求状态，响应状态为200表示请求成功
print(type(r.text))    #查看类型。 r.text——文本获取。 r.content——图片、音频获取。
print(len(r.text))    # 查看文本长度
# Out:
# 200
# <class 'str'>
# 375715

# %%
# 将字符串格式转为json格式。
import json
data_json = json.loads(r.text)
data_json.keys()    # data键存放着需要的数据
# Out:
# dict_keys(['reqId', 'code', 'msg', 'data', 'timestamp'])

# %%
data = data_json['data'] # 取出json中的数据
data.keys()
# Out:
# dict_keys(['chinaTotal', 'chinaDayList', 'lastUpdateTime', 'overseaLastUpdateTime', 'areaTree'])

# %% [markdown]
# # 世界各国实时数据获取 today_data

# %%
# 将提取数据的方法封装为函数
def get_data(data,info_list):
    info = pd.DataFrame(data)[info_list] # 主要信息
    
    today_data = pd.DataFrame([i['today'] for i in data ]) # 生成today的数据
    today_data.columns = ['today_'+i for i in today_data.columns] # 修改列名
    
    total_data = pd.DataFrame([i['total'] for i in data ]) # 生成total的数据
    total_data.columns = ['total_'+i for i in total_data.columns] # 修改列名
    
    return pd.concat([info,total_data,today_data],axis=1) # info、today和total横向合并最终得到汇总的数据

# 定义保存数据方法
def save_data(data,name): 
    file_name = name+'_'+time.strftime('%Y_%m_%d',time.localtime(time.time()))+'.csv'
    data.to_csv(file_name,index=None,encoding='utf_8_sig')
    print(file_name+' 保存成功！')
time.strftime('%Y_%m_%d',time.localtime(time.time()))
# Out:
# '2021_01_07'

# %%
areaTree = data['areaTree'] # 取出 areaTree——世界各地实时数据
areaTree[0] # 查看第一个国家的数据
# Out:
# {'today': {'confirm': 2820,
#   'suspect': None,
#   'heal': 1275,
#   'dead': 70,
#   'severe': None,
#   'storeConfirm': None},
#  'total': {'confirm': 149881,
#   'suspect': 0,
#   'heal': 111599,
#   'dead': 5004,
#   'severe': 0,
#   'input': 0},
#  'extData': {},
#  'name': '突尼斯',
#  'id': '9577772',
#  'lastUpdateTime': '2021-01-07 08:23:02',
#  'children': []}

# %%
for i in range(len(areaTree)):  # 查看各国家名称和更新时间
    print(areaTree[i]['name'],areaTree[i]['lastUpdateTime'])
    if i == 5:
        break
# Out:
# 突尼斯 2021-01-07 08:23:02
# 塞尔维亚 2021-01-07 08:23:02
# 中国 2021-01-07 08:22:58
# 日本本土 2021-01-07 08:23:02
# 泰国 2021-01-07 08:23:01
# 新加坡 2021-01-07 08:23:02

# %%
today_world = get_data(areaTree,['id','lastUpdateTime','name'])
today_world.head()   # 查看获取数据的前5行
# Out:
#         id       lastUpdateTime  name  total_confirm  total_dead  total_heal  \
# 0  9577772  2021-01-07 08:23:02   突尼斯         149881        5004      111599
# 1  9507896  2021-01-07 08:23:02  塞尔维亚         352120        3444           0
# 2        0  2021-01-07 08:22:58    中国          97217        4795       91106
# 3        1  2021-01-07 08:23:02  日本本土         259495        3609      206883
# 4        2  2021-01-07 08:23:01    泰国           9331          66        4418
#
#    total_input  total_severe  total_suspect  today_confirm  today_dead  \
# 0          0.0             0              0         2820.0        70.0
# 1          0.0             0              0         2882.0         0.0
# 2       4359.0             0              0           90.0         1.0
# 3          0.0             0              0         6009.0         0.0
# 4          0.0             0              0          365.0         0.0
#
#    today_heal  today_input  today_severe  today_storeConfirm  today_suspect
# 0      1275.0          NaN           NaN                 NaN            NaN
# 1         0.0          NaN           NaN                 NaN            NaN
# 2        98.0         11.0           NaN                -9.0            NaN
# 3         0.0          NaN           NaN                 NaN            NaN
# 4         0.0          NaN           NaN                 NaN            NaN

# %%
save_data(today_world,'today_world')
# Out:
# today_world_2021_01_07.csv 保存成功！

# %% [markdown]
# # 世界各国历史数据获取 alltime_world

# %%
today_world[['id','name']].head()
country_dict = {key:value for key,value in zip(today_world['id'], today_world['name'])}

# 查看前五个内容
count = 0
for i in country_dict:
    print(i,country_dict[i])
    count += 1
    if count == 5:
        break
# Out:
# 9577772 突尼斯
# 9507896 塞尔维亚
# 0 中国
# 1 日本本土
# 2 泰国

# %%
start = time.time()
for country_id in country_dict: # 遍历每个国家的编号
    
    try:
        # 按照编号访问每个国家的数据地址，并获取json数据
        url = 'https://c.m.163.com/ug/api/wuhan/app/data/list-by-area-code?areaCode='+country_id
        r = requests.get(url, headers=headers)
        json_data = json.loads(r.text)
        
        # 生成每个国家的数据
        country_data = get_data(json_data['data']['list'],['date'])
        country_data['name'] = country_dict[country_id]

        # 数据叠加
        if country_id == '9577772':
            alltime_world = country_data
        else:
            alltime_world = pd.concat([alltime_world,country_data])
            
        print('-'*20,country_dict[country_id],'成功',country_data.shape,alltime_world.shape,
              ',累计耗时:',round(time.time()-start),'-'*20)
        
        time.sleep(10)

    except:
        print('-'*20,country_dict[country_id],'wrong','-'*20)
# Out:
# -------------------- 突尼斯 成功 (293, 15) (293, 15) ,累计耗时: 0 --------------------
# -------------------- 塞尔维亚 成功 (298, 15) (591, 15) ,累计耗时: 10 --------------------
# -------------------- 中国 成功 (335, 15) (926, 15) ,累计耗时: 21 --------------------
# -------------------- 日本本土 成功 (312, 15) (1238, 15) ,累计耗时: 31 --------------------
# -------------------- 泰国 成功 (309, 15) (1547, 15) ,累计耗时: 41 --------------------
# -------------------- 新加坡 成功 (326, 15) (1873, 15) ,累计耗时: 51 --------------------
# -------------------- 韩国 成功 (349, 15) (2222, 15) ,累计耗时: 61 --------------------
# -------------------- 澳大利亚 成功 (308, 15) (2530, 15) ,累计耗时: 72 --------------------
# -------------------- 德国 成功 (315, 15) (2845, 15) ,累计耗时: 82 --------------------
# -------------------- 美国 成功 (320, 15) (3165, 15) ,累计耗时: 92 --------------------
# -------------------- 马来西亚 成功 (312, 15) (3477, 15) ,累计耗时: 102 --------------------
# -------------------- 越南 成功 (283, 15) (3760, 15) ,累计耗时: 112 --------------------
# -------------------- 圣巴泰勒米 成功 (30, 15) (3790, 15) ,累计耗时: 123 --------------------
# -------------------- 肯尼亚 成功 (287, 15) (4077, 15) ,累计耗时: 133 --------------------
# -------------------- 伊朗 成功 (320, 15) (4397, 15) ,累计耗时: 143 --------------------
# -------------------- 以色列 成功 (312, 15) (4709, 15) ,累计耗时: 153 --------------------
# -------------------- 毛利亚尼亚 成功 (12, 15) (4721, 15) ,累计耗时: 163 --------------------
# -------------------- 黎巴嫩 成功 (295, 15) (5016, 15) ,累计耗时: 174 --------------------
# -------------------- 克罗地亚 成功 (296, 15) (5312, 15) ,累计耗时: 184 --------------------
# -------------------- 奥地利 成功 (306, 15) (5618, 15) ,累计耗时: 194 --------------------
# -------------------- 瑞士 成功 (312, 15) (5930, 15) ,累计耗时: 204 --------------------
# -------------------- 希腊 成功 (301, 15) (6231, 15) ,累计耗时: 214 --------------------
# -------------------- 毛里求斯 成功 (273, 15) (6504, 15) ,累计耗时: 225 --------------------
# -------------------- 爱沙尼亚 成功 (295, 15) (6799, 15) ,累计耗时: 235 --------------------
# -------------------- 北马其顿 成功 (285, 15) (7084, 15) ,累计耗时: 245 --------------------
# -------------------- 白俄罗斯 成功 (290, 15) (7374, 15) ,累计耗时: 255 --------------------
# -------------------- 立陶宛 成功 (292, 15) (7666, 15) ,累计耗时: 265 --------------------
# -------------------- 阿塞拜疆 成功 (291, 15) (7957, 15) ,累计耗时: 276 --------------------
# -------------------- 美属维尔京群岛 成功 (30, 15) (7987, 15) ,累计耗时: 286 --------------------
# -------------------- 蒙古 成功 (61, 15) (8048, 15) ,累计耗时: 296 --------------------
# -------------------- 乌克兰 成功 (295, 15) (8343, 15) ,累计耗时: 306 --------------------
# -------------------- 波兰 成功 (300, 15) (8643, 15) ,累计耗时: 316 --------------------
# -------------------- 波黑 成功 (287, 15) (8930, 15) ,累计耗时: 327 --------------------
# -------------------- 蒙特塞拉特 成功 (34, 15) (8964, 15) ,累计耗时: 337 --------------------
# -------------------- 南非 成功 (301, 15) (9265, 15) ,累计耗时: 347 --------------------
# -------------------- 布隆迪 成功 (40, 15) (9305, 15) ,累计耗时: 357 --------------------
# -------------------- 南苏丹 成功 (48, 15) (9353, 15) ,累计耗时: 367 --------------------
# -------------------- 马耳他 成功 (272, 15) (9625, 15) ,累计耗时: 377 --------------------
# -------------------- 摩尔多瓦 成功 (289, 15) (9914, 15) ,累计耗时: 388 --------------------
# -------------------- 保加利亚 成功 (293, 15) (10207, 15) ,累计耗时: 398 --------------------
# -------------------- 孟加拉 成功 (283, 15) (10490, 15) ,累计耗时: 408 --------------------
# -------------------- 阿尔巴尼亚 成功 (88, 15) (10578, 15) ,累计耗时: 418 --------------------
# -------------------- 巴勒斯坦 成功 (283, 15) (10861, 15) ,累计耗时: 429 --------------------
# -------------------- 科摩罗 成功 (34, 15) (10895, 15) ,累计耗时: 439 --------------------
# -------------------- 阿富汗 成功 (291, 15) (11186, 15) ,累计耗时: 449 --------------------
# -------------------- 沙特阿拉伯 成功 (303, 15) (11489, 15) ,累计耗时: 459 --------------------
# -------------------- 新西兰 成功 (296, 15) (11785, 15) ,累计耗时: 469 --------------------
# -------------------- 塔吉克斯坦 成功 (241, 15) (12026, 15) ,累计耗时: 480 --------------------
# -------------------- 泽西岛 成功 (30, 15) (12056, 15) ,累计耗时: 490 --------------------
# -------------------- 叙利亚 成功 (50, 15) (12106, 15) ,累计耗时: 500 --------------------
# -------------------- 巴拿马 成功 (286, 15) (12392, 15) ,累计耗时: 510 --------------------
# -------------------- 古巴 成功 (274, 15) (12666, 15) ,累计耗时: 520 --------------------
# -------------------- 尼日利亚 成功 (293, 15) (12959, 15) ,累计耗时: 531 --------------------
# -------------------- 摩洛哥 成功 (300, 15) (13259, 15) ,累计耗时: 541 --------------------
# -------------------- 塞内加尔 成功 (296, 15) (13555, 15) ,累计耗时: 551 --------------------
# -------------------- 老挝 成功 (44, 15) (13599, 15) ,累计耗时: 561 --------------------
# -------------------- 巴哈马 成功 (249, 15) (13848, 15) ,累计耗时: 571 --------------------
# -------------------- 马约特岛 成功 (40, 15) (13888, 15) ,累计耗时: 582 --------------------
# -------------------- 斯洛文尼亚 成功 (289, 15) (14177, 15) ,累计耗时: 592 --------------------
# -------------------- 卢森堡 成功 (294, 15) (14471, 15) ,累计耗时: 602 --------------------
# -------------------- 爱尔兰 成功 (303, 15) (14774, 15) ,累计耗时: 612 --------------------
# -------------------- 厄瓜多尔 成功 (290, 15) (15064, 15) ,累计耗时: 622 --------------------
# -------------------- 捷克 成功 (304, 15) (15368, 15) ,累计耗时: 633 --------------------
# -------------------- 匈牙利 成功 (302, 15) (15670, 15) ,累计耗时: 643 --------------------
# -------------------- 法属圭亚那 成功 (48, 15) (15718, 15) ,累计耗时: 653 --------------------
# -------------------- 多哥共和国 成功 (68, 15) (15786, 15) ,累计耗时: 663 --------------------
# -------------------- 哥斯达黎加 成功 (278, 15) (16064, 15) ,累计耗时: 673 --------------------
# -------------------- 文莱 成功 (267, 15) (16331, 15) ,累计耗时: 684 --------------------
# -------------------- 法罗群岛 成功 (47, 15) (16378, 15) ,累计耗时: 694 --------------------
# -------------------- 马提尼克岛 成功 (244, 15) (16622, 15) ,累计耗时: 704 --------------------
# -------------------- 荷兰 成功 (313, 15) (16935, 15) ,累计耗时: 714 --------------------
# -------------------- 巴西 成功 (306, 15) (17241, 15) ,累计耗时: 724 --------------------
# -------------------- 洪都拉斯 成功 (270, 15) (17511, 15) ,累计耗时: 735 --------------------
# -------------------- 乌拉圭 成功 (283, 15) (17794, 15) ,累计耗时: 745 --------------------
# -------------------- 秘鲁 成功 (298, 15) (18092, 15) ,累计耗时: 755 --------------------
# -------------------- 智利 成功 (305, 15) (18397, 15) ,累计耗时: 765 --------------------
# -------------------- 格陵兰 成功 (37, 15) (18434, 15) ,累计耗时: 775 --------------------
# -------------------- 圣巴托洛谬岛 成功 (30, 15) (18464, 15) ,累计耗时: 786 --------------------
# -------------------- 马尔代夫 成功 (270, 15) (18734, 15) ,累计耗时: 796 --------------------
# -------------------- 委内瑞拉 成功 (267, 15) (19001, 15) ,累计耗时: 806 --------------------
# -------------------- 毛里塔尼亚 成功 (255, 15) (19256, 15) ,累计耗时: 816 --------------------
# -------------------- 纳米比亚 成功 (44, 15) (19300, 15) ,累计耗时: 826 --------------------
# -------------------- 法属留尼汪岛 成功 (41, 15) (19341, 15) ,累计耗时: 837 --------------------
# -------------------- 波多黎各 成功 (47, 15) (19388, 15) ,累计耗时: 847 --------------------
# -------------------- 加纳 成功 (275, 15) (19663, 15) ,累计耗时: 857 --------------------
# -------------------- 赤道几内亚 成功 (259, 15) (19922, 15) ,累计耗时: 867 --------------------
# -------------------- 几内亚 成功 (280, 15) (20202, 15) ,累计耗时: 877 --------------------
# -------------------- 卢旺达 成功 (280, 15) (20482, 15) ,累计耗时: 888 --------------------
# -------------------- 格林纳达 成功 (39, 15) (20521, 15) ,累计耗时: 898 --------------------
# -------------------- 斯威士兰 成功 (260, 15) (20781, 15) ,累计耗时: 908 --------------------
# -------------------- 坦桑尼亚 成功 (262, 15) (21043, 15) ,累计耗时: 918 --------------------
# -------------------- 贝宁 成功 (256, 15) (21299, 15) ,累计耗时: 928 --------------------
# -------------------- 刚果（金） 成功 (286, 15) (21585, 15) ,累计耗时: 939 --------------------
# -------------------- 中非共和国 成功 (255, 15) (21840, 15) ,累计耗时: 949 --------------------
# -------------------- 利比里亚 成功 (257, 15) (22097, 15) ,累计耗时: 959 --------------------
# -------------------- 索马里 成功 (264, 15) (22361, 15) ,累计耗时: 969 --------------------
# -------------------- 塞拉利昂 成功 (259, 15) (22620, 15) ,累计耗时: 980 --------------------
# -------------------- 乍得 成功 (254, 15) (22874, 15) ,累计耗时: 990 --------------------
# -------------------- 赞比亚 成功 (273, 15) (23147, 15) ,累计耗时: 1000 --------------------
# -------------------- 巴巴多斯 成功 (52, 15) (23199, 15) ,累计耗时: 1010 --------------------
# -------------------- 马里 成功 (275, 15) (23474, 15) ,累计耗时: 1020 --------------------
# -------------------- 阿根廷 成功 (299, 15) (23773, 15) ,累计耗时: 1031 --------------------
# -------------------- 法属波利尼西亚 成功 (36, 15) (23809, 15) ,累计耗时: 1041 --------------------
# -------------------- 巴林 成功 (304, 15) (24113, 15) ,累计耗时: 1051 --------------------
# -------------------- 莫桑比克 成功 (266, 15) (24379, 15) ,累计耗时: 1061 --------------------
# -------------------- 喀麦隆 成功 (280, 15) (24659, 15) ,累计耗时: 1072 --------------------
# -------------------- 乌干达 成功 (277, 15) (24936, 15) ,累计耗时: 1082 --------------------
# -------------------- 厄立特里亚 成功 (50, 15) (24986, 15) ,累计耗时: 1092 --------------------
# -------------------- 刚果（布） 成功 (261, 15) (25247, 15) ,累计耗时: 1102 --------------------
# -------------------- 津巴布韦 成功 (265, 15) (25512, 15) ,累计耗时: 1112 --------------------
# -------------------- 丹麦 成功 (309, 15) (25821, 15) ,累计耗时: 1123 --------------------
# -------------------- 阿鲁巴 成功 (34, 15) (25855, 15) ,累计耗时: 1133 --------------------
# -------------------- 斐济 成功 (244, 15) (26099, 15) ,累计耗时: 1143 --------------------
# -------------------- 伯利兹 成功 (244, 15) (26343, 15) ,累计耗时: 1153 --------------------
# -------------------- 缅甸 成功 (270, 15) (26613, 15) ,累计耗时: 1163 --------------------
# -------------------- 塞浦路斯 成功 (290, 15) (26903, 15) ,累计耗时: 1174 --------------------
# -------------------- 关岛 成功 (33, 15) (26936, 15) ,累计耗时: 1185 --------------------
# -------------------- 科索沃 成功 (34, 15) (26970, 15) ,累计耗时: 1195 --------------------
# -------------------- 圣皮埃尔岛和密克隆岛 成功 (21, 15) (26991, 15) ,累计耗时: 1205 --------------------
# -------------------- 吉尔吉斯斯坦 成功 (276, 15) (27267, 15) ,累计耗时: 1215 --------------------
# -------------------- 博茨瓦纳 成功 (38, 15) (27305, 15) ,累计耗时: 1225 --------------------
# -------------------- 尼日尔 成功 (277, 15) (27582, 15) ,累计耗时: 1236 --------------------
# -------------------- 苏里南 成功 (246, 15) (27828, 15) ,累计耗时: 1246 --------------------
# -------------------- 佛得角 成功 (258, 15) (28086, 15) ,累计耗时: 1256 --------------------
# -------------------- 萨尔瓦多 成功 (258, 15) (28344, 15) ,累计耗时: 1266 --------------------
# -------------------- 圭亚那 成功 (60, 15) (28404, 15) ,累计耗时: 1277 --------------------
# -------------------- 尼加拉瓜 成功 (248, 15) (28652, 15) ,累计耗时: 1287 --------------------
# -------------------- 冈比亚 成功 (41, 15) (28693, 15) ,累计耗时: 1297 --------------------
# -------------------- 东帝汶 成功 (38, 15) (28731, 15) ,累计耗时: 1307 --------------------
# -------------------- 巴基斯坦 成功 (305, 15) (29036, 15) ,累计耗时: 1317 --------------------
# -------------------- 埃及 成功 (303, 15) (29339, 15) ,累计耗时: 1328 --------------------
# -------------------- 科威特 成功 (302, 15) (29641, 15) ,累计耗时: 1338 --------------------
# -------------------- 斯洛伐克 成功 (289, 15) (29930, 15) ,累计耗时: 1348 --------------------
# -------------------- 直布罗陀 成功 (39, 15) (29969, 15) ,累计耗时: 1358 --------------------
# -------------------- 摩纳哥 成功 (69, 15) (30038, 15) ,累计耗时: 1368 --------------------
# -------------------- 巴拉圭 成功 (273, 15) (30311, 15) ,累计耗时: 1379 --------------------
# -------------------- 荷属安的列斯 成功 (27, 15) (30338, 15) ,累计耗时: 1389 --------------------
# -------------------- 多米尼克 成功 (38, 15) (30376, 15) ,累计耗时: 1399 --------------------
# -------------------- 乌兹别克斯坦 成功 (289, 15) (30665, 15) ,累计耗时: 1409 --------------------
# -------------------- 黑山 成功 (272, 15) (30937, 15) ,累计耗时: 1420 --------------------
# -------------------- 危地马拉 成功 (265, 15) (31202, 15) ,累计耗时: 1430 --------------------
# -------------------- 加蓬 成功 (276, 15) (31478, 15) ,累计耗时: 1440 --------------------
# -------------------- 苏丹 成功 (271, 15) (31749, 15) ,累计耗时: 1450 --------------------
# -------------------- 利比亚 成功 (260, 15) (32009, 15) ,累计耗时: 1460 --------------------
# -------------------- 圣马丁岛 成功 (36, 15) (32045, 15) ,累计耗时: 1471 --------------------
# -------------------- 土耳其 成功 (300, 15) (32345, 15) ,累计耗时: 1481 --------------------
# -------------------- 巴布亚新几内亚 成功 (36, 15) (32381, 15) ,累计耗时: 1491 --------------------
# -------------------- 多米尼加 成功 (276, 15) (32657, 15) ,累计耗时: 1501 --------------------
# -------------------- 约旦 成功 (288, 15) (32945, 15) ,累计耗时: 1511 --------------------
# -------------------- 亚美尼亚 成功 (294, 15) (33239, 15) ,累计耗时: 1522 --------------------
# -------------------- 圣基茨和尼维斯 成功 (39, 15) (33278, 15) ,累计耗时: 1532 --------------------
# -------------------- 瓜德罗普 成功 (40, 15) (33318, 15) ,累计耗时: 1542 --------------------
# -------------------- 安提瓜和巴布达 成功 (241, 15) (33559, 15) ,累计耗时: 1552 --------------------
# -------------------- 玻利维亚 成功 (270, 15) (33829, 15) ,累计耗时: 1562 --------------------
# -------------------- 哥伦比亚 成功 (293, 15) (34122, 15) ,累计耗时: 1573 --------------------
# -------------------- 圣文森特和格林纳丁斯 成功 (37, 15) (34159, 15) ,累计耗时: 1583 --------------------
# -------------------- 圣卢西亚 成功 (37, 15) (34196, 15) ,累计耗时: 1593 --------------------
# -------------------- 法国 成功 (316, 15) (34512, 15) ,累计耗时: 1603 --------------------
# -------------------- 阿联酋 成功 (303, 15) (34815, 15) ,累计耗时: 1613 --------------------
# -------------------- 加拿大 成功 (314, 15) (35129, 15) ,累计耗时: 1624 --------------------
# -------------------- 印度 成功 (310, 15) (35439, 15) ,累计耗时: 1634 --------------------
# -------------------- 英国 成功 (316, 15) (35755, 15) ,累计耗时: 1644 --------------------
# -------------------- 意大利 成功 (338, 15) (36093, 15) ,累计耗时: 1654 --------------------
# -------------------- 俄罗斯 成功 (308, 15) (36401, 15) ,累计耗时: 1665 --------------------
# -------------------- 菲律宾 成功 (304, 15) (36705, 15) ,累计耗时: 1675 --------------------
# -------------------- 芬兰 成功 (308, 15) (37013, 15) ,累计耗时: 1685 --------------------
# -------------------- 尼泊尔 成功 (260, 15) (37273, 15) ,累计耗时: 1695 --------------------
# -------------------- 葡萄牙 成功 (299, 15) (37572, 15) ,累计耗时: 1705 --------------------
# -------------------- 也门 成功 (244, 15) (37816, 15) ,累计耗时: 1716 --------------------
# -------------------- 塞舌尔 成功 (41, 15) (37857, 15) ,累计耗时: 1726 --------------------
# -------------------- 西班牙 成功 (317, 15) (38174, 15) ,累计耗时: 1736 --------------------
# -------------------- 斯里兰卡 成功 (292, 15) (38466, 15) ,累计耗时: 1746 --------------------
# -------------------- 阿尔及利亚 成功 (296, 15) (38762, 15) ,累计耗时: 1757 --------------------
# -------------------- 柬埔寨 成功 (260, 15) (39022, 15) ,累计耗时: 1767 --------------------
# -------------------- 海地 成功 (254, 15) (39276, 15) ,累计耗时: 1777 --------------------
# -------------------- 瑞典 成功 (309, 15) (39585, 15) ,累计耗时: 1787 --------------------
# -------------------- 特里尼达和多巴哥 成功 (45, 15) (39630, 15) ,累计耗时: 1797 --------------------
# -------------------- 吉布提 成功 (271, 15) (39901, 15) ,累计耗时: 1808 --------------------
# -------------------- 圣多美与普林西比 成功 (36, 15) (39937, 15) ,累计耗时: 1818 --------------------
# -------------------- 布基纳法索 成功 (287, 15) (40224, 15) ,累计耗时: 1828 --------------------
# -------------------- 比利时 成功 (310, 15) (40534, 15) ,累计耗时: 1838 --------------------
# -------------------- 伊拉克 成功 (311, 15) (40845, 15) ,累计耗时: 1848 --------------------
# -------------------- 马拉维 成功 (252, 15) (41097, 15) ,累计耗时: 1859 --------------------
# -------------------- 冰岛 成功 (297, 15) (41394, 15) ,累计耗时: 1869 --------------------
# -------------------- 几内亚比绍 成功 (258, 15) (41652, 15) ,累计耗时: 1879 --------------------
# -------------------- 拉脱维亚 成功 (295, 15) (41947, 15) ,累计耗时: 1889 --------------------
# -------------------- 不丹 成功 (43, 15) (41990, 15) ,累计耗时: 1899 --------------------
# -------------------- 挪威 成功 (310, 15) (42300, 15) ,累计耗时: 1910 --------------------
# -------------------- 印度尼西亚 成功 (301, 15) (42601, 15) ,累计耗时: 1920 --------------------
# -------------------- 安哥拉 成功 (256, 15) (42857, 15) ,累计耗时: 1930 --------------------
# -------------------- 开曼群岛 成功 (37, 15) (42894, 15) ,累计耗时: 1940 --------------------
# -------------------- 埃塞俄比亚 成功 (275, 15) (43169, 15) ,累计耗时: 1951 --------------------
# -------------------- 梵蒂冈 成功 (42, 15) (43211, 15) ,累计耗时: 1961 --------------------
# -------------------- 科特迪瓦 成功 (288, 15) (43499, 15) ,累计耗时: 1971 --------------------
# -------------------- 卡塔尔 成功 (303, 15) (43802, 15) ,累计耗时: 1981 --------------------
# -------------------- 莱索托 成功 (26, 15) (43828, 15) ,累计耗时: 2101 --------------------
# -------------------- 格鲁吉亚 成功 (295, 15) (44123, 15) ,累计耗时: 2111 --------------------
# -------------------- 墨西哥 成功 (300, 15) (44423, 15) ,累计耗时: 2122 --------------------
# -------------------- 圣马力诺 成功 (268, 15) (44691, 15) ,累计耗时: 2132 --------------------
# -------------------- 哈萨克斯坦 成功 (293, 15) (44984, 15) ,累计耗时: 2142 --------------------
# -------------------- 安道尔 成功 (278, 15) (45262, 15) ,累计耗时: 2152 --------------------
# -------------------- 牙买加 成功 (262, 15) (45524, 15) ,累计耗时: 2163 --------------------
# -------------------- 格恩西岛 成功 (29, 15) (45553, 15) ,累计耗时: 2173 --------------------
# -------------------- 罗马尼亚 成功 (302, 15) (45855, 15) ,累计耗时: 2183 --------------------
# -------------------- 阿曼 成功 (303, 15) (46158, 15) ,累计耗时: 2193 --------------------
# -------------------- 列支敦士登 成功 (48, 15) (46206, 15) ,累计耗时: 2203 --------------------
# -------------------- 马达加斯加 成功 (266, 15) (46472, 15) ,累计耗时: 2214 --------------------

# %%
save_data(alltime_world,'alltime_world')
# Out:
# alltime_world_2021_01_07.csv 保存成功！

# %% [markdown]
# # 数据预处理

# %%
#读取数据疫情数据alltime_world_2020_05_31.csv
import pandas as pd
alltime_world = pd.read_csv('alltime_world_2021_01_07.csv', encoding='utf-8')   # 1）读文件
print( alltime_world.info() )     # 2）查看基本信息
name_dict = {'date':'日期','name':'名称','id':'编号','lastUpdateTime':'更新时间',
             'today_confirm':'当日新增确诊','today_suspect':'当日新增疑似',
             'today_heal':'当日新增治愈','today_dead':'当日新增死亡',
             'today_severe':'当日新增重症','today_storeConfirm':'当日现存确诊', 'today_input':'当日输入',
             'total_confirm':'累计确诊','total_suspect':'累计疑似','total_heal':'累计治愈',
             'total_dead':'累计死亡','total_severe':'累计重症','total_input':'累计输入'}   # 3）创建中文列名字典
alltime_world.rename(columns=name_dict, inplace=True)   # 4)将英文列名更改中文列名
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46472 entries, 0 to 46471
# Data columns (total 15 columns):
# date                  46472 non-null object
# total_confirm         46472 non-null int64
# total_dead            46472 non-null int64
# total_heal            46472 non-null int64
# total_input           46472 non-null int64
# total_severe          46472 non-null int64
# total_suspect         46472 non-null int64
# today_confirm         46472 non-null int64
# today_dead            46472 non-null int64
# today_heal            46472 non-null int64
# today_input           46276 non-null float64
# today_severe          12509 non-null float64
# today_storeConfirm    0 non-null float64
# today_suspect         12909 non-null float64
# name                  46472 non-null object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 5.3+ MB
# None

# %%
## 使用下面属性和函数查看数据的大概信息
alltime_world.info()   # 查看二维数据表的大信息
print('\n\n查看二维数据表的统计消息，统计数值型数据: \n', alltime_world.describe() )
print('\n\n查看二维数据表的列标签：\n', alltime_world.columns )
print('\n\n查看二维数据表的行标签：\n', alltime_world.index )
print('\n\n查看二维数据表的值：\n', alltime_world.values )
print('\n\n查看二维数据表的前5行：\n', alltime_world.head() )
print('\n\n查看二维数据表的后5行：\n', alltime_world.tail() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46472 entries, 0 to 46471
# Data columns (total 15 columns):
# 日期        46472 non-null object
# 累计确诊      46472 non-null int64
# 累计死亡      46472 non-null int64
# 累计治愈      46472 non-null int64
# 累计输入      46472 non-null int64
# 累计重症      46472 non-null int64
# 累计疑似      46472 non-null int64
# 当日新增确诊    46472 non-null int64
# 当日新增死亡    46472 non-null int64
# 当日新增治愈    46472 non-null int64
# 当日输入      46276 non-null float64
# 当日新增重症    12509 non-null float64
# 当日现存确诊    0 non-null float64
# 当日新增疑似    12909 non-null float64
# 名称        46472 non-null object
# dtypes: float64(4), int64(9), object(2)
# memory usage: 5.3+ MB
#
#
# 查看二维数据表的统计消息，统计数值型数据:
#                 累计确诊           累计死亡          累计治愈          累计输入          累计重症  \
# count  4.647200e+04   46472.000000  4.647200e+04  46472.000000  46472.000000
# mean   1.739744e+05    4996.287657  1.193124e+05     15.413905      2.380810
# std    8.830433e+05   20634.889600  6.413046e+05    209.917572    103.685836
# min    0.000000e+00       0.000000  0.000000e+00      0.000000      0.000000
# 25%    1.289000e+03      24.000000  5.150000e+02      0.000000      0.000000
# 50%    8.887000e+03     157.000000  4.943000e+03      0.000000      0.000000
# 75%    7.170250e+04    1408.000000  4.035375e+04      0.000000      0.000000
# max    2.177736e+07  368792.000000  1.296847e+07   4359.000000   7365.000000
#
#                累计疑似         当日新增确诊        当日新增死亡        当日新增治愈          当日输入  \
# count  46472.000000   46472.000000  46472.000000  4.647200e+04  46276.000000
# mean       5.893527    1881.348834     40.552698  1.325393e+03      0.094196
# std      321.784752   10533.292041    181.197391  9.261605e+03      3.650378
# min        0.000000  -65415.000000  -6464.000000 -3.444680e+05    -19.000000
# 25%        0.000000       5.000000      0.000000  0.000000e+00      0.000000
# 50%        0.000000      78.000000      1.000000  2.300000e+01      0.000000
# 75%        0.000000     637.000000     11.000000  3.400000e+02      0.000000
# max    28942.000000  880962.000000   7057.000000  1.151187e+06    723.000000
#
#              当日新增重症  当日现存确诊        当日新增疑似
# count  12509.000000     0.0  12909.000000
# mean      -0.581341     NaN      3.528314
# std       12.372097     NaN     95.676476
# min     -464.000000     NaN      0.000000
# 25%        0.000000     NaN      0.000000
# 50%        0.000000     NaN      0.000000
# 75%        0.000000     NaN      0.000000
# max        0.000000     NaN   4008.000000
#
#
# 查看二维数据表的列标签：
#  Index(['日期', '累计确诊', '累计死亡', '累计治愈', '累计输入', '累计重症', '累计疑似', '当日新增确诊',
#        '当日新增死亡', '当日新增治愈', '当日输入', '当日新增重症', '当日现存确诊', '当日新增疑似', '名称'],
#       dtype='object')
#
#
# 查看二维数据表的行标签：
#  RangeIndex(start=0, stop=46472, step=1)
#
#
# 查看二维数据表的值：
#  [['2020-03-03' 1 0 ... nan 0.0 '突尼斯']
#  ['2020-03-08' 2 0 ... nan 0.0 '突尼斯']
#  ['2020-03-09' 5 0 ... nan 0.0 '突尼斯']
#  ...
#  ['2021-01-04' 17767 262 ... nan nan '马达加斯加']
#  ['2021-01-05' 17767 262 ... nan nan '马达加斯加']
#  ['2021-01-07' 17767 262 ... nan nan '马达加斯加']]
#
#
# 查看二维数据表的前5行：
#             日期  累计确诊  累计死亡  累计治愈  累计输入  累计重症  累计疑似  当日新增确诊  当日新增死亡  当日新增治愈  \
# 0  2020-03-03     1     0     0     0     0     0       1       0       0
# 1  2020-03-08     2     0     0     0     0     0       1       0       0
# 2  2020-03-09     5     0     0     0     0     0       3       0       0
# 3  2020-03-11     7     0     0     0     0     0       2       0       0
# 4  2020-03-12    13     0     0     0     0     0       6       0       0
#
#    当日输入  当日新增重症  当日现存确诊  当日新增疑似   名称
# 0   NaN     NaN     NaN     0.0  突尼斯
# 1   0.0     0.0     NaN     0.0  突尼斯
# 2   0.0     0.0     NaN     0.0  突尼斯
# 3   0.0     0.0     NaN     0.0  突尼斯
# 4   0.0     0.0     NaN     0.0  突尼斯
#
#
# 查看二维数据表的后5行：
#                 日期   累计确诊  累计死亡   累计治愈  累计输入  累计重症  累计疑似  当日新增确诊  当日新增死亡  \
# 46467  2021-01-02  17714   261  17228     0     0     0       0       0
# 46468  2021-01-03  17767   262  17298     0     0     0      53       1
# 46469  2021-01-04  17767   262  17298     0     0     0       0       0
# 46470  2021-01-05  17767   262  17298     0     0     0       0       0
# 46471  2021-01-07  17767   262  17298     0     0     0       0       0
#
#        当日新增治愈  当日输入  当日新增重症  当日现存确诊  当日新增疑似     名称
# 46467       0   0.0     NaN     NaN     NaN  马达加斯加
# 46468      70   0.0     NaN     NaN     NaN  马达加斯加
# 46469       0   0.0     NaN     NaN     NaN  马达加斯加
# 46470       0   0.0     NaN     NaN     NaN  马达加斯加
# 46471       0   0.0     NaN     NaN     NaN  马达加斯加

# %%
# 计算缺失值比例
alltime_world_nan = alltime_world.isnull().sum()/len(alltime_world)
# 转变为百分数
alltime_world_nan.apply(lambda x: format(x, '.1%'))
# Out:
# 日期          0.0%
# 累计确诊        0.0%
# 累计死亡        0.0%
# 累计治愈        0.0%
# 累计输入        0.0%
# 累计重症        0.0%
# 累计疑似        0.0%
# 当日新增确诊      0.0%
# 当日新增死亡      0.0%
# 当日新增治愈      0.0%
# 当日输入        0.4%
# 当日新增重症     73.1%
# 当日现存确诊    100.0%
# 当日新增疑似     72.2%
# 名称          0.0%
# dtype: object

# %%
# 先使用线性插值的方式填充缺失值
alltime_world.interpolate(method='linear', inplace=True)

# 再使用0填充缺失值
alltime_world.fillna(0, inplace=True)

# 计算当日现存确诊人数（当日现存确诊=累计确诊-累计治愈-累计死亡）
alltime_world['当日现存确诊'] = alltime_world['累计确诊']-alltime_world['累计治愈']-alltime_world['累计死亡']

# 将日期改成datetime格式
alltime_world['日期'] = pd.to_datetime(alltime_world['日期'])

alltime_world.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46472 entries, 0 to 46471
# Data columns (total 15 columns):
# 日期        46472 non-null datetime64[ns]
# 累计确诊      46472 non-null int64
# 累计死亡      46472 non-null int64
# 累计治愈      46472 non-null int64
# 累计输入      46472 non-null int64
# 累计重症      46472 non-null int64
# 累计疑似      46472 non-null int64
# 当日新增确诊    46472 non-null int64
# 当日新增死亡    46472 non-null int64
# 当日新增治愈    46472 non-null int64
# 当日输入      46472 non-null float64
# 当日新增重症    46472 non-null float64
# 当日现存确诊    46472 non-null int64
# 当日新增疑似    46472 non-null float64
# 名称        46472 non-null object
# dtypes: datetime64[ns](1), float64(3), int64(10), object(1)
# memory usage: 5.3+ MB
