# %% [markdown]
# # 1.探索Chipotle快餐数据

# %% [markdown]
#  （1）将数据存入一个chipo的数据框内

# %%
import pandas
chipo='chipotle.csv'
chipo=pandas.read_csv(chipo)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# （2）查看前十行内容

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# （3）数据集中有多少列

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# （4）打印出全部列的名称

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# （5）数据集的索引是怎么样的

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# （6）被下单最多的产品（item）是什么

# %%
chipo.groupby(['item_name']).sum().sort_values(by=['quantity'],ascending=False)
# Out:
#                                        order_id  quantity
# item_name
# Chicken Bowl                             713926       761
# Chicken Burrito                          497303       591
# Chips and Guacamole                      449959       506
# Steak Burrito                            328437       386
# Canned Soft Drink                        304753       351
# Chips                                    208004       230
# Steak Bowl                               193752       221
# Bottled Water                            175944       211
# Chips and Fresh Tomato Salsa             100419       130
# Canned Soda                               76396       126
# Chicken Salad Bowl                       117104       123
# Chicken Soft Tacos                        98395       120
# Side of Chips                             84769       110
# Veggie Burrito                            80962        97
# Barbacoa Burrito                          74718        91
# ...

# %%
# chipo['quantity'].value_counts().idxmin()
# Out:
# 15

# %%
chipo[['item_name','quantity']].groupby(by=['item_name']).sum().sort_values(by=['quantity'],ascending=True)
# Out:
#                                        quantity
# item_name
# Carnitas Salad                                1
# Veggie Crispy Tacos                           1
# Chips and Mild Fresh Tomato Salsa             1
# Crispy Tacos                                  2
# Salad                                         2
# Bowl                                          4
# Steak Salad                                   4
# Veggie Salad                                  6
# Carnitas Salad Bowl                           6
# Burrito                                       6
# Carnitas Crispy Tacos                         8
# Veggie Soft Tacos                             8
# Chicken Salad                                 9
# Barbacoa Salad Bowl                          10
# Barbacoa Crispy Tacos                        12
# Veggie Salad Bowl                            18
# Chips and Roasted Chili-Corn Salsa           18
# Izze                                         20
# ...

# %%
chipo.item_name.nunique()
# Out:
# 50

# %%
chipo['item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
chipo_sum=chipo['quantity'].sum()
chipo_sum
# Out:
# 4972

# %%
chipo[['item_price']].astype('float')
chipo[['item_price']]
# Out:
#       item_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4          16.98
# ...          ...
# 4617       11.75
# 4618       11.75
# 4619       11.25
# 4620        8.75
# 4621        8.75
#
# [4622 rows x 1 columns]

# %%
chipo['total']=chipo['item_price'] * chipo['quantity']
chipo['total'].sum()
# Out:
# 39237.02

# %%
chipo.order_id.nunique()
# Out:
# 1834

# %%
chipo['price_sum']=chipo['quantity']*chipo['item_price']
(chipo[['order_id','price_sum']].groupby(by=['order_id']).sum()).mean()
# Out:
# price_sum    21.394231
# dtype: float64

# %% [markdown]
# # 2.探索2012欧洲杯数据

# %% [markdown]
# (1)将数据存入一个euro12的数据框内

# %%
import pandas as pd
euro12_filename='Euro2012.csv'
euro12=pd.read_csv(euro12_filename)
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# (2)只选取Goals这一列

# %%
a = euro12['Goals']
a
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# (3)有多少球队参加了2012欧洲杯

# %%
print(a.shape)
# Out:
# (16,)

# %% [markdown]
# (4)该数据集中一共有多少列（columns）

# %%
b = euro12.columns.size
print(b)
# Out:
# 35

# %% [markdown]
# （5）将数据集中的列Team,Yellow Cards和Red Cards单独存为一个名叫discipline得数据框

# %%
discipline = euro12[['Team','Yellow Cards','Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# (6)对数据框discipline先按照Red Cards排序然后按照Yellow Cards排序

# %%
c = discipline.sort_values(by = ['Red Cards','Yellow Cards'],axis=0,ascending = True)
c
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# (7)计算每个球队拿到黄牌数的平均值

# %%
round(discipline['Yellow Cards'].mean())
# Out:
# 7

# %% [markdown]
# (8)找到进球数Goals超过6的球队数据

# %%
euro12.loc[euro12["Goals"] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# (9)选取以字母G开头的球队数据

# %%
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# (10)选取前七列

# %%
d = euro12.T.copy()
d = d.head(7).T
d
# Out:
#                    Team Goals Shots on target Shots off target  \
# 0               Croatia     4              13               12
# 1        Czech Republic     4              13               18
# 2               Denmark     4              10               10
# 3               England     5              11               18
# 4                France     3              22               24
# 5               Germany    10              32               32
# 6                Greece     5               8               18
# 7                 Italy     6              34               45
# 8           Netherlands     2              12               36
# 9                Poland     2              15               23
# 10             Portugal     6              22               42
# 11  Republic of Ireland     1               7               12
# 12               Russia     5               9               31
# 13                Spain    12              42               33
# ...

# %% [markdown]
# （11）选取除最后3列以外的全部列

# %%
e = euro12.T.copy()
e = e.head(b-3).T
e
# Out:
#                    Team Goals Shots on target Shots off target  \
# 0               Croatia     4              13               12
# 1        Czech Republic     4              13               18
# 2               Denmark     4              10               10
# 3               England     5              11               18
# 4                France     3              22               24
# 5               Germany    10              32               32
# 6                Greece     5               8               18
# 7                 Italy     6              34               45
# 8           Netherlands     2              12               36
# 9                Poland     2              15               23
# 10             Portugal     6              22               42
# 11  Republic of Ireland     1               7               12
# 12               Russia     5               9               31
# 13                Spain    12              42               33
# ...

# %% [markdown]
# （12） 找到英格兰(England)、意大利(Italy)和俄罗斯(Russia)的射正率(ShootingAccuracy)。

# %%
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # 3，探索酒类消费数据

# %% [markdown]
# （1）. 将数据框命名为drinks；

# %%
import pandas as pd
drinks_filename='drinks.csv'
drinks=pd.read_csv(drinks_filename)
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# （2）. 哪个大陆(continent)平均消耗的啤酒(beer)更多？

# %%
a = drinks.groupby(['continent']).mean().sort_values(
    by = 'beer_servings',ascending = False)
a
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# EU            193.777778       132.555556     142.222222
# SA            175.083333       114.750000      62.416667
# OC             89.687500        58.437500      35.625000
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
#
#            total_litres_of_pure_alcohol
# continent
# EU                             8.617778
# SA                             6.308333
# OC                             3.381250
# AF                             3.007547
# AS                             2.170455

# %% [markdown]
# （3）. 打印出每个大陆(continent)的红酒消耗(wine_servings)的描述性统计值；

# %%
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# （4）. 打印出每个大陆每种酒类别的消耗平均值；

# %%
drinks.groupby('continent').agg(['mean'])
# Out:
#           beer_servings spirit_servings wine_servings  \
#                    mean            mean          mean
# continent
# AF            61.471698       16.339623     16.264151
# AS            37.045455       60.840909      9.068182
# EU           193.777778      132.555556    142.222222
# OC            89.687500       58.437500     35.625000
# SA           175.083333      114.750000     62.416667
#
#           total_litres_of_pure_alcohol
#                                   mean
# continent
# AF                            3.007547
# AS                            2.170455
# EU                            8.617778
# OC                            3.381250
# SA                            6.308333

# %% [markdown]
# （5）. 打印出每个大陆每种酒类别的消耗中位数；

# %%
drinks.groupby('continent').agg(['median'])
# Out:
#           beer_servings spirit_servings wine_servings  \
#                  median          median        median
# continent
# AF                 32.0             3.0           2.0
# AS                 17.5            16.0           1.0
# EU                219.0           122.0         128.0
# OC                 52.5            37.0           8.5
# SA                162.5           108.5          12.0
#
#           total_litres_of_pure_alcohol
#                                 median
# continent
# AF                                2.30
# AS                                1.20
# EU                               10.00
# OC                                1.75
# SA                                6.85

# %% [markdown]
# （6）. 打印出每个大陆对spirit_servings饮品消耗的平均值，最大值和最小值。

# %%
drinks.groupby('continent').spirit_servings.agg(['mean','max','min'])
# Out:
#                  mean  max  min
# continent
# AF          16.339623  152    0
# AS          60.840909  326    0
# EU         132.555556  373    0
# OC          58.437500  254    0
# SA         114.750000  302   25

# %% [markdown]
# # 4，探索1960 -2014美国犯罪数据

# %% [markdown]
# （1）. 将数据框命名为crime；

# %%
import pandas as pd
crime_filename = 'US_Crime_Rates_1960_2014.csv'
crime = pd.read_csv(crime_filename)
crime.head()
# Out:
#    Unnamed: 0  Year  Population    Total  Violent  Property  Murder  \
# 0           0  1960   179323175  3384200   288460   3095700    9110
# 1           1  1961   182992000  3488000   289390   3198600    8740
# 2           2  1962   185771000  3752200   301510   3450700    8530
# 3           3  1963   188483000  4109500   316970   3792500    8640
# 4           4  1964   191141000  4564600   364220   4200400    9360
#
#    Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# 0          17190   107840              154320    912100        1855400
# 1          17220   106670              156760    949600        1913000
# 2          17550   110860              164570    994300        2089600
# 3          17650   116470              174210   1086400        2297800
# 4          21420   130390              203050   1213200        2514400
#
#    Vehicle_Theft
# 0         328200
# 1         336000
# 2         366800
# 3         408300
# 4         472800

# %% [markdown]
# （2）. 每一列(column)的数据类型是什么样的？

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 13 columns):
# Unnamed: 0            55 non-null int64
# Year                  55 non-null int64
# Population            55 non-null int64
# Total                 55 non-null int64
# Violent               55 non-null int64
# Property              55 non-null int64
# Murder                55 non-null int64
# Forcible_Rape         55 non-null int64
# Robbery               55 non-null int64
# Aggravated_assault    55 non-null int64
# Burglary              55 non-null int64
# Larceny_Theft         55 non-null int64
# Vehicle_Theft         55 non-null int64
# dtypes: int64(13)
# memory usage: 5.7 KB

# %% [markdown]
# （3）. 将Year的数据类型转换为datetime64；

# %%
crime.Year = pd.to_datetime(crime.Year,format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 13 columns):
# Unnamed: 0            55 non-null int64
# Year                  55 non-null datetime64[ns]
# Population            55 non-null int64
# Total                 55 non-null int64
# Violent               55 non-null int64
# Property              55 non-null int64
# Murder                55 non-null int64
# Forcible_Rape         55 non-null int64
# Robbery               55 non-null int64
# Aggravated_assault    55 non-null int64
# Burglary              55 non-null int64
# Larceny_Theft         55 non-null int64
# Vehicle_Theft         55 non-null int64
# dtypes: datetime64[ns](1), int64(12)
# memory usage: 5.7 KB

# %% [markdown]
# （4）. 将列Year设置为数据框的索引；

# %%
crime = crime.set_index('Year', drop = True)
crime.head()
# Out:
#             Unnamed: 0  Population    Total  Violent  Property  Murder  \
# Year
# 1960-01-01           0   179323175  3384200   288460   3095700    9110
# 1961-01-01           1   182992000  3488000   289390   3198600    8740
# 1962-01-01           2   185771000  3752200   301510   3450700    8530
# 1963-01-01           3   188483000  4109500   316970   3792500    8640
# 1964-01-01           4   191141000  4564600   364220   4200400    9360
#
#             Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# Year
# 1960-01-01          17190   107840              154320    912100
# 1961-01-01          17220   106670              156760    949600
# 1962-01-01          17550   110860              164570    994300
# 1963-01-01          17650   116470              174210   1086400
# 1964-01-01          21420   130390              203050   1213200
#
#             Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01        1855400         328200
# 1961-01-01        1913000         336000
# ...

# %% [markdown]
# （5）. 删除名为Total的列；

# %%
del crime['Total']
crime.head()
# Out:
#             Unnamed: 0  Population  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01           0   179323175   288460   3095700    9110          17190
# 1961-01-01           1   182992000   289390   3198600    8740          17220
# 1962-01-01           2   185771000   301510   3450700    8530          17550
# 1963-01-01           3   188483000   316970   3792500    8640          17650
# 1964-01-01           4   191141000   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %% [markdown]
# （6）. 按照Year（每十年）对数据框进行分组并求和；

# %%
crimes = crime.resample('10AS').sum()
Population1 = crime['Population'].resample('10AS').max()
crimes['Population'] = Population1
crimes
# Out:
#             Unnamed: 0  Population   Violent   Property  Murder  \
# Year
# 1960-01-01          45   201385000   4134930   45160900  106180
# 1970-01-01         145   220099000   9607930   91383800  192230
# 1980-01-01         245   248239000  14074328  117048900  206439
# 1990-01-01         345   272690813  17527048  119053499  211664
# 2000-01-01         445   307006550  13968056  100944369  163068
# 2010-01-01         260   318857056   6072017   44095950   72867
#
#             Forcible_Rape  Robbery  Aggravated_assault  Burglary  \
# Year
# 1960-01-01         236720  1633510             2158520  13321100
# 1970-01-01         554570  4159020             4702120  28486000
# 1980-01-01         865639  5383109             7619130  33073494
# 1990-01-01         998827  5748930            10568963  26750015
# 2000-01-01         922499  4230366             8652124  21565176
# 2010-01-01         421059  1749809             3764142  10125170
#
#             Larceny_Theft  Vehicle_Theft
# ...

# %% [markdown]
# （7）. 何时是美国历史上生存最危险的年代？

# %%
crimes.idxmax()
# Out:
# Unnamed: 0           2000-01-01
# Population           2010-01-01
# Violent              1990-01-01
# Property             1990-01-01
# Murder               1990-01-01
# Forcible_Rape        1990-01-01
# Robbery              1990-01-01
# Aggravated_assault   1990-01-01
# Burglary             1980-01-01
# Larceny_Theft        1990-01-01
# Vehicle_Theft        1990-01-01
# dtype: datetime64[ns]

# %% [markdown]
# # 5， 探索虚拟姓名数据

# %% [markdown]
# （1）. 创建DataFrame；

# %%
import pandas as pd
import numpy as np

raw_data_1 = {
'subject_id': ['1', '2', '3', '4', '5'],
'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
'subject_id': ['4', '5', '6', '7', '8'],
'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %% [markdown]
# （2）. 将上述的DataFrame分别命名为data1, data2, data3；

# %%
data1 = pd.DataFrame(raw_data_1,columns=['subject_id','first_name','last_name'])
data1
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
data2 = pd.DataFrame(raw_data_2,columns=['subject_id','first_name','last_name'])
data2
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
data3 = pd.DataFrame(raw_data_3,columns=['subject_id','test_id'])
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# （3）. 将data1和data2两个数据框按照行的维度进行合并，命名为all_data；

# %%
all_data = pd.concat([data1,data2])
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# （4）. 将data1和data2两个数据框按照列的维度进行合并，命名为all_data_col；

# %%
all_data_col = pd.concat([data1,data2],axis=1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %% [markdown]
# （5）. 打印data3；

# %%
print(data3)
data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %% [markdown]
# （6）. 按照subject_id的值对all_data和data3作合并

# %%
pd.merge(all_data,data3,on = 'subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %% [markdown]
# （7）. 对data1和data2按照subject_id作连接；

# %%
pd.merge(data1,data2,on = 'subject_id')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# （8）. 找到data1和data2合并之后的所有匹配结果。

# %%
pd.merge(data1,data2,on = 'subject_id',how = 'outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# # 6， 探索Apple公司股价数据

# %% [markdown]
# （1）. 读取数据并存为一个名叫apple的数据框。

# %%
import pandas as pd
apple_filename = 'appl_1980_2014.csv'
apple = pd.read_csv(apple_filename)
apple
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# （2）. 查看每一列的数据类型。

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
# Date         8465 non-null object
# Open         8465 non-null float64
# High         8465 non-null float64
# Low          8465 non-null float64
# Close        8465 non-null float64
# Volume       8465 non-null int64
# Adj Close    8465 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.1+ KB

# %% [markdown]
# （3）. 将Date这个列转换为datetime类型。

# %%
apple.Date = pd.to_datetime(apple.Date)
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
# Date         8465 non-null datetime64[ns]
# Open         8465 non-null float64
# High         8465 non-null float64
# Low          8465 non-null float64
# Close        8465 non-null float64
# Volume       8465 non-null int64
# Adj Close    8465 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 463.1 KB

# %% [markdown]
# （4）. 将Date设置为索引。

# %%
apple = apple.set_index('Date',drop=True)
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# 5）. 有重复的日期吗？

# %%
apple.index.is_unique
# Out:
# True

# %% [markdown]
# （6）. 将index设置为升序

# %%
apple.sort_index(ascending = True)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...           ...    ...    ...    ...        ...        ...
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 6 columns]

# %% [markdown]
# （7）. 找到每个月的最后一个交易日(businessday)。

# %%
businessday = apple.resample('BM').mean()
businessday.head()
# Out:
#                  Open       High        Low      Close        Volume  \
# Date
# 1980-12-31  30.481538  30.567692  30.443077  30.443077  2.586252e+07
# 1981-01-30  31.754762  31.826667  31.654762  31.654762  7.249867e+06
# 1981-02-27  26.480000  26.572105  26.407895  26.407895  4.231832e+06
# 1981-03-31  24.937727  25.016818  24.836364  24.836364  7.962691e+06
# 1981-04-30  27.286667  27.368095  27.227143  27.227143  6.392000e+06
#
#             Adj Close
# Date
# 1980-12-31   0.473077
# 1981-01-30   0.493810
# 1981-02-27   0.411053
# 1981-03-31   0.387727
# 1981-04-30   0.423333

# %% [markdown]
# （8）. 数据集中最早的日期和最晚的日期相差多少天？

# %%
(apple.index.max() - apple.index.min()).days
# Out:
# 12261

# %% [markdown]
# （9）. 在数据中一共有多少个月？

# %%
len(businessday)
# Out:
# 404

# %% [markdown]
# （10）. 按照时间顺序可视化AdjClose值。

# %%
apple['Adj Close'].plot(title = 'Time')

# %% [markdown]
# # 7， 招聘数据探索与分析

# %% [markdown]
# （1）.读取数据并存为一个名叫job_info的数据框；

# %%
import pandas as pd
job_info_filename = 'job_info.csv'
job_info = pd.read_csv(job_info_filename,encoding = 'GBK',header=None)
job_info
# Out:
#                              0        1        2           3      4
# 0                         字节跳动   数据产品经理       北京    2-3.5万/月  09-03
# 1              甲骨文（中国）软件系统有限公司   数据产品经理       长沙         NaN  09-03
# 2     莱茵技术(上海)有限公司 TUV Rhei...   数据产品经理   上海-静安区         NaN  09-03
# 3          百度在线网络技术（北京）有限公司...   数据产品经理       北京      2-4万/月  09-03
# 4                     携程旅行网业务区   数据产品经理   上海-长宁区    1.5-2万/月  09-03
# ...                        ...      ...      ...         ...    ...
# 5495              深圳市创荣发电子有限公司  仓库数据分析员       深圳    2-2.5万/月  09-04
# 5496            深圳市宝华诚投资管理有限公司  仓库数据分析员  深圳-龙华新区      6-8千/月  09-04
# 5497               广州市卡思投资有限公司  仓库数据分析员   深圳-福田区    0.8-1万/月  09-04
# 5498            深圳市迪比科电子科技有限公司  仓库数据分析员  深圳-龙华新区  1.5-2.5万/月  09-04
# 5499                武汉锦瑞技术有限公司  仓库数据分析员   武汉-蔡甸区    3-4.5千/月  09-04
#
# [5500 rows x 5 columns]

# %% [markdown]
# （2）.将列命名为：['公司', '岗位', '工作地点', '工资', '发布日期']；

# %%
job_info.columns = ['公司','岗位','工作地点','工资','发布日期']
job_info
# Out:
#                             公司       岗位     工作地点          工资   发布日期
# 0                         字节跳动   数据产品经理       北京    2-3.5万/月  09-03
# 1              甲骨文（中国）软件系统有限公司   数据产品经理       长沙         NaN  09-03
# 2     莱茵技术(上海)有限公司 TUV Rhei...   数据产品经理   上海-静安区         NaN  09-03
# 3          百度在线网络技术（北京）有限公司...   数据产品经理       北京      2-4万/月  09-03
# 4                     携程旅行网业务区   数据产品经理   上海-长宁区    1.5-2万/月  09-03
# ...                        ...      ...      ...         ...    ...
# 5495              深圳市创荣发电子有限公司  仓库数据分析员       深圳    2-2.5万/月  09-04
# 5496            深圳市宝华诚投资管理有限公司  仓库数据分析员  深圳-龙华新区      6-8千/月  09-04
# 5497               广州市卡思投资有限公司  仓库数据分析员   深圳-福田区    0.8-1万/月  09-04
# 5498            深圳市迪比科电子科技有限公司  仓库数据分析员  深圳-龙华新区  1.5-2.5万/月  09-04
# 5499                武汉锦瑞技术有限公司  仓库数据分析员   武汉-蔡甸区    3-4.5千/月  09-04
#
# [5500 rows x 5 columns]

# %% [markdown]
# （3）.哪个岗位招聘需求最多？

# %%
job_info['岗位'].value_counts()
# Out:
# 数据分析师      4000
# 数据产品经理     1000
# 仓库数据分析员     400
# 数据库管理员      100
# Name: 岗位, dtype: int64

# %%
job_info['岗位'].value_counts().idxmax()
# Out:
# '数据分析师'

# %% [markdown]
# （4）.取出9月3日发布的招聘信息；

# %%
job_info['发布日期'].value_counts()
# Out:
# 09-03    5315
# 09-04     179
# 09-02       2
# 08-30       1
# 08-12       1
# 08-29       1
# 08-20       1
# Name: 发布日期, dtype: int64

# %%
job_info[job_info['发布日期'] == '09-03']
# Out:
#                             公司       岗位    工作地点          工资   发布日期
# 0              甲骨文（中国）软件系统有限公司   数据产品经理      长沙         NaN  09-03
# 1     莱茵技术(上海)有限公司 TUV Rhei...   数据产品经理  上海-静安区         NaN  09-03
# 2          百度在线网络技术（北京）有限公司...   数据产品经理      北京      2-4万/月  09-03
# 3                     携程旅行网业务区   数据产品经理  上海-长宁区    1.5-2万/月  09-03
# 4          嘉吉投资（中国）有限公司南京分公...   数据产品经理      南京         NaN  09-03
# ...                        ...      ...     ...         ...    ...
# 5347            无锡明恒混合动力技术有限公司  仓库数据分析员  无锡-惠山区  0.9-1.6万/月  09-03
# 5348              四川良柏财税咨询有限公司  仓库数据分析员  成都-青羊区    4.5-6千/月  09-03
# 5349       陕西斯达防爆安全科技股份有限公司...  仓库数据分析员      西安  0.8-1.5万/月  09-03
# 5350                珠海文景科技有限公司  仓库数据分析员    异地招聘    1-1.5万/月  09-03
# 5351              广州友财信息科技有限公司  仓库数据分析员  广州-天河区  1.3-2.5万/月  09-03
#
# [5314 rows x 5 columns]

# %% [markdown]
# （5）.找出工作地点在深圳的数据分析师招聘信息；

# %%
a = job_info.loc[:,'工作地点'].value_counts()
a.head(20)
# Out:
# 广州-天河区     275
# 上海-浦东新区    190
# 异地招聘       187
# 上海         174
# 深圳-南山区     168
# 广州         124
# 广州-白云区     117
# 上海-徐汇区     116
# 深圳-福田区     110
# 深圳-龙岗区     107
# 深圳-宝安区      95
# 深圳-龙华新区     93
# 武汉-洪山区      92
# 深圳          91
# 上海-闵行区      83
# 上海-静安区      72
# 成都-高新区      71
# 广州-海珠区      71
# 北京-朝阳区      70
# 北京-海淀区      65
# Name: 工作地点, dtype: int64

# %%
b = job_info[job_info['工作地点'].apply(lambda x:'深圳' in x)]
b
# Out:
#                        公司       岗位     工作地点          工资   发布日期
# 12         深圳市腾讯计算机系统有限公司   数据产品经理       深圳         NaN  09-03
# 16          深圳市大疆创新科技有限公司   数据产品经理   深圳-南山区    1-1.5万/月  09-03
# 20           金蝶软件（中国）有限公司   数据产品经理       深圳      1-2万/月  09-03
# 21           传智播客教育集团深圳分校   数据产品经理   深圳-宝安区    2.5-3万/月  09-03
# 32    深圳市隆汇达投资咨询服务有限公司...   数据产品经理   深圳-罗湖区    0.8-1万/月  09-03
# ...                   ...      ...      ...         ...    ...
# 5483         深圳金丰星际科技有限公司  仓库数据分析员  深圳-龙华新区      5-8千/月  09-04
# 5495         深圳市创荣发电子有限公司  仓库数据分析员       深圳    2-2.5万/月  09-04
# 5496       深圳市宝华诚投资管理有限公司  仓库数据分析员  深圳-龙华新区      6-8千/月  09-04
# 5497          广州市卡思投资有限公司  仓库数据分析员   深圳-福田区    0.8-1万/月  09-04
# 5498       深圳市迪比科电子科技有限公司  仓库数据分析员  深圳-龙华新区  1.5-2.5万/月  09-04
#
# [716 rows x 5 columns]

# %%
c = b[b['岗位'] == '数据分析师']
c.head()
# Out:
#                        公司     岗位    工作地点          工资   发布日期
# 1001        深圳市众联软件科技有限公司  数据分析师  深圳-龙岗区      6-8千/月  09-03
# 1002        深圳市田田家园家具有限公司  数据分析师  深圳-宝安区    3-4.5千/月  09-03
# 1012           深圳爱嘻科技有限公司  数据分析师  深圳-龙岗区  0.8-1.5万/月  09-03
# 1016  瑞庭网络技术（上海）有限公司深圳...  数据分析师      深圳      7-9千/月  09-03
# 1023        深圳市成达网络科技有限公司  数据分析师  深圳-南山区    1-1.5万/月  09-03

# %% [markdown]
# （6）.取出每个岗位的最低工资与最高工资，单位为“元/月”，若招聘信息中无工资数据则无需处理。（如2-2.5万/月，则最低工资为20000，最高工资为25000。）

# %%
job_info['工资'].str[-3:].value_counts()    #只处理一下按年和按月给工资
# Out:
# 千/月    2785
# 万/月    2330
# 万/年     219
# 元/天      51
# /小时       6
# 下/月       1
# Name: 工资, dtype: int64

# %%
import re
def get_number(string =None):
    try:
        if string[-3] == '万':
            x = [float(i)*10000 for i in re.findall('\d+\.{0,1}\d*', string)]
        elif string[-3] == '千':
            x = [float(i)*1000 for i in re.findall('\d+\.{0,1}\d*', string)]
        if string[-1] == '年':
            x = [i/12 for i in x]
        return x
    except:
        return None
job_info['最低月薪']=job_info['工资'].apply(get_number).str[0]
job_info['最高月薪']=job_info['工资'].apply(get_number).str[1]

# %%
job_info['最低月薪']
job_info['最高月薪']
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 5494    None
# 5495    None
# 5496    None
# 5497    None
# 5498    None
# Name: 最高月薪, Length: 5499, dtype: object
