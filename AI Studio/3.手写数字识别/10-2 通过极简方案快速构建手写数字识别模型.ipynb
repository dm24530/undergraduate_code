# %% [markdown]
# ### 配置环境

# %%
# !python3 -m pip --version # 查看pip版本
# !python -m pip install --upgrade pip #更新pip版本
# !python -m pip install paddlepaddle==1.7.2 -i https://mirror.baidu.com/pypi/simple #下载paddle1.8.5版本
# !python -m pip install paddlepaddle==2.0.1 -i https://mirror.baidu.com/pypi/simple
# !pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL
# ERROR: No matching distribution found for PIL

# %%
import paddle
import paddle.fluid as fluid
from paddle.fluid.dygraph.nn import Linear
import numpy as np
import os
# from PTL import Image

# %%
trainset = paddle.mnist.train()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c1e955dc523a> in <module>()
# ----> 1 trainset = paddle.mnist.train()
#
# AttributeError: module 'paddle' has no attribute 'mnist'
