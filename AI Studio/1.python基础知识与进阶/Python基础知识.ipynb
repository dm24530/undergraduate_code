# %% [markdown]
# # 数字

# %%
import math
print(math.ceil(4.1))   #上入整数
print(math.floor(4.9))   #下舍整数
print(math.fabs(-10))
print(math.sqrt(9))
print(math.exp(1))
# Out:
# 5
# 4
# 10.0
# 3.0
# 2.718281828459045

# %% [markdown]
# # 字符串

# %%
new_str = '-'.join('Hello')
print(new_str)
# Out:
# H-e-l-l-o

# %%
print("The \t is a tab")
# Out:
# The 	 is a tab

# %% [markdown]
# # 添加

# %%
girls = []
#append(),追加
girls.append('杨超越')
print(girls)
# Out:
# ['杨超越']

# %%
#extend一次性添加多个
models = ['刘雯','奚梦瑶']
girls.extend(models)
print(girls)
# Out:
# ['杨超越', '刘雯', '奚梦瑶']

# %%
#insert()：指定位置添加
girls.insert(1,'虞书欣')
print(girls)
# Out:
# ['杨超越', '虞书欣', '刘雯', '奚梦瑶']

# %% [markdown]
# # 删除

# %%
words = ['cat','hello','pen','pencil','ruler']
del words[1]
print(words)
# Out:
# ['cat', 'pen', 'pencil', 'ruler']

# %%
words = ['cat','hello','pen','pencil','ruler']
words.remove('cat')
print(words)
# Out:
# ['hello', 'pen', 'pencil', 'ruler']

# %%
words = ['cat','hello','pen','pencil','ruler']
words.pop(1)
print(words)
# Out:
# ['cat', 'pen', 'pencil', 'ruler']

# %% [markdown]
# # 切片

# %%
words = ['cat','hello','pen','pencil','ruler']
print(words[::2])
# Out:
# ['cat', 'pen', 'ruler']

# %%
print(words[-5:-1:2])
# Out:
# ['cat', 'pen']

# %% [markdown]
# # 排序

# %%
import random
random_list = []
for i in range(10):
  ran = random.randint(1,20)
  if ran not in random_list:
    random_list.append(ran)
    i+=1
print(random_list)
# Out:
# [1, 12, 8, 15, 5, 18, 9, 13, 6]

# %%
#默认升序
new_list = sorted(random_list)
print(new_list)
# Out:
# [1, 5, 6, 8, 9, 12, 13, 15, 18]

# %%
#降序
new_list = sorted(random_list, reverse=True)
print(new_list)
# Out:
# [18, 15, 13, 12, 9, 8, 6, 5, 1]

# %% [markdown]
# # 元组

# %%
tuple1 = ()
print(type(tuple1))
# Out:
# <class 'tuple'>

# %%
typle2 = ('hello')
print(type(typle2))
# Out:
# <class 'str'>

# %%
#元组中只有一个元素需要在最后加逗号
typle3 = ('hello',)
print(type(typle3))
# Out:
# <class 'tuple'>

# %%
#在元组中存放元素
import random
random_list = []
for i in range(10):
  ran = random.randint(1,20)
  random_list.append(ran)
print(random_list)

random_tuple = tuple(random_list)
print(random_tuple)
# Out:
# [11, 13, 16, 6, 1, 5, 4, 12, 3, 11]
# (11, 13, 16, 6, 1, 5, 4, 12, 3, 11)

# %%
print(random_tuple[::-1])
# Out:
# (11, 3, 12, 4, 5, 1, 6, 16, 13, 11)

# %%
print(sum(random_tuple))
print(min(random_tuple))
print(max(random_tuple))
print(len(random_tuple))
# Out:
# 82
# 1
# 16
# 10

# %%
#统计元组中4的个数
print(random_tuple.count(4))
# Out:
# 1

# %%
#统计元组中4对应的下标
print(random_tuple.index(4))
# Out:
# 6

# %%
t1 = (1,2,3)+(4,5)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
#元组的拆包与装包
t3 = (1,2,3)
a,b,c = t3
print(a,b,c)
# Out:
# 1 2 3

# %%
t4 = (1,2,3,4,5)
a,b,*c = t4
print(a,b,c)
print(c)
print(*c)
# Out:
# 1 2 [3, 4, 5]
# [3, 4, 5]
# 3 4 5

# %% [markdown]
# # 字典

# %%
dict5 = {'杨超越':165, '虞书欣':166, '上官喜爱':164}
print(dict5.items())
# Out:
# dict_items([('杨超越', 165), ('虞书欣', 166), ('上官喜爱', 164)])

# %%
for key,value in dict5.items():
  if value > 165:
    print(key)
# Out:
# 虞书欣

# %%
print(dict5.get('赵小棠'))
#如果能取到值，则返回字典中的值，否则返回默认170
print(dict5.get('赵小棠',170))
# Out:
# None
# 170

# %%
#删除可以用del, pop

# %% [markdown]
# # python面向对象

# %%
class Animal:
  def __init__(self, name):
    self.name = name
    print('动物名称实例化')
  def eat(self):
    print(self.name + '要吃东西啦！')
  def drink(self):
    print(self.name + '要喝水啦！')
  
cat = Animal('miaomiao')
print(cat.name)
cat.eat()
cat.drink()
# Out:
# 动物名称实例化
# miaomiao
# miaomiao要吃东西啦！
# miaomiao要喝水啦！

# %%
class Person:
  def __init__(self, name):
    self.name = name
    print('调用父类构造函数')
  def eat(self):
    print('调用父类方法')
class Student(Person):
  def __init__(self):
    print('调用子类构造方法')
  def study(self):
    print('调用子类方法')
s = Student()
s.study()
s.eat()
# Out:
# 调用子类构造方法
# 调用子类方法
# 调用父类方法

# %% [markdown]
# # python JSON

# %%
import json
data = [{'b':2, "d":4, 'a':1, "c":3, "e":5}]
json_format = json.dumps(data, sort_keys=True, indent=4, separators=(',',':'))
print(json_format)
# Out:
# [
#     {
#         "a":1,
#         "b":2,
#         "c":3,
#         "d":4,
#         "e":5
#     }
# ]

# %%
import json
jsonData = '{"b":2, "d":4, "a":1, "c":3, "e":5}'
text = json.loads(jsonData)
print(text)
# Out:
# {'b': 2, 'd': 4, 'a': 1, 'c': 3, 'e': 5}

# %% [markdown]
# # Python异常处理

# %%
try:
  fh = open('hello.txt',"w")
  fh.write("这是一个测试文件，用于测试异常！！")
except IOError:
  print("Error:没有找到文件或读取文件失败")
else:
  print('内容写入成功')
  fh.close()
# Out:
# 内容写入成功

# %%
try:
  f = open('hello.text', "w")
  f.write("这是一个测试文件，用于检测异常！！")
finally:
  print('关闭文件')
  f.close()
# Out:
# 关闭文件
