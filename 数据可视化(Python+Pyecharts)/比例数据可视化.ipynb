# %%
# 导入pandas和numpy
import pandas as pd
import numpy as np
data = np.arange(1, 10)
index = np.arange(11, 20)
s = pd.Series(data, index=index)
s
# Out:
# 11    1
# 12    2
# 13    3
# 14    4
# 15    5
# 16    6
# 17    7
# 18    8
# 19    9
# dtype: int32

# %%
s = pd.Series(np.random.rand(5), index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    0.751280
# b    0.160398
# c    0.574098
# d    0.593847
# e    0.044903
# dtype: float64

# %%
s = pd.Series(np.random.rand(5))
s
# Out:
# 0    0.319889
# 1    0.887660
# 2    0.052491
# 3    0.385821
# 4    0.403192
# dtype: float64

# %%
d = {'a': 1, 'b': 3, 'c': 5}
pd.Series(d)
# Out:
# a    1
# b    3
# c    5
# dtype: int64

# %%
pd.Series(d, index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    1.0
# b    3.0
# c    5.0
# d    NaN
# e    NaN
# dtype: float64

# %%
pd.Series([x for x in range(1, 5)], list('abcd'))
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
pd.Series([x for x in range(1, 5)])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s = pd.Series(np.random.rand(3), index=['a', 'b', 'c'])
print("s[0]:\n", s[0])
print("s['b']:\n", s['b'])
# Out:
# s[0]:
#  0.6808780237012945
# s['b']:
#  0.8039394884981665

# %%
print("'a' in s: \n", 'a' in s)
print("'f' in s: \n", 'f' in s)
try:
    print("s['f']: \n", s['f'])
except KeyError:
    print(KeyError)
print("s.get('b'): \n", s.get('b'))
print("s.get('f'):\n", s.get('f'))
print("s.get('f', 'f不在索引列表中'):\n", s.get('f', 'f不在索引列表中'))
# Out:
# 'a' in s:
#  True
# 'f' in s:
#  False
# <class 'KeyError'>
# s.get('b'):
#  0.8039394884981665
# s.get('f'):
#  None
# s.get('f', 'f不在索引列表中'):
#  f不在索引列表中

# %%
print("s[:3]:\n{}".format(s[:3]))
print("s[:'c']:\n{}".format(s[:'c']))
print("s[1:3]:\n{}".format(s[1:3]))
print("s[[1,2]]:\n{}".format(s[[1,2]]))
# Out:
# s[:3]:
# a    0.680878
# b    0.803939
# c    0.543132
# dtype: float64
# s[:'c']:
# a    0.680878
# b    0.803939
# c    0.543132
# dtype: float64
# s[1:3]:
# b    0.803939
# c    0.543132
# dtype: float64
# s[[1,2]]:
# b    0.803939
# c    0.543132
# dtype: float64

# %%
# 生成从2018年9月1日开始，十天的时间序列索引，频率为10分钟
rng = pd.date_range('9/1/2018', periods=1440, freq='10Min')
rng[:5]
# Out:
# DatetimeIndex(['2018-09-01 00:00:00', '2018-09-01 00:10:00',
#                '2018-09-01 00:20:00', '2018-09-01 00:30:00',
#                '2018-09-01 00:40:00'],
#               dtype='datetime64[ns]', freq='10T')

# %%
ts = pd.Series(np.random.rand(1440), index=rng)
ts.head()
# Out:
# 2018-09-01 00:00:00    0.566621
# 2018-09-01 00:10:00    0.522399
# 2018-09-01 00:20:00    0.068799
# 2018-09-01 00:30:00    0.795320
# 2018-09-01 00:40:00    0.803441
# Freq: 10T, dtype: float64

# %%
ts.count()
# Out:
# 1440

# %%
ts[:5]
# Out:
# 2018-09-01 00:00:00    0.566621
# 2018-09-01 00:10:00    0.522399
# 2018-09-01 00:20:00    0.068799
# 2018-09-01 00:30:00    0.795320
# 2018-09-01 00:40:00    0.803441
# Freq: 10T, dtype: float64

# %%
ts[:10:2]
# Out:
# 2018-09-01 00:00:00    0.566621
# 2018-09-01 00:20:00    0.068799
# 2018-09-01 00:40:00    0.803441
# 2018-09-01 01:00:00    0.399131
# 2018-09-01 01:20:00    0.796323
# Freq: 20T, dtype: float64

# %%
# 时间字符串索引
ts['9/6/2018'][140:]
# Out:
# 2018-09-06 23:20:00    0.401164
# 2018-09-06 23:30:00    0.081843
# 2018-09-06 23:40:00    0.415628
# 2018-09-06 23:50:00    0.269693
# Freq: 10T, dtype: float64

# %%
# datetime类型的索引
from datetime import datetime
ts[datetime(2018, 9, 9):][::60]
# Out:
# 2018-09-09 00:00:00    0.343626
# 2018-09-09 10:00:00    0.998729
# 2018-09-09 20:00:00    0.187074
# 2018-09-10 06:00:00    0.875246
# 2018-09-10 16:00:00    0.037678
# Freq: 600T, dtype: float64

# %%
df1 = pd.DataFrame({'name': ['hellof', 'masonsxu', 'a', 'b', 'c']})
df2 = pd.DataFrame({'name': ['hellof', 'masonsxu', 'A', 'B', 'C']})
pd.merge(df1, df2, on='name')
# Out:
#        name
# 0    hellof
# 1  masonsxu

# %%
pd.merge(df1, df2, how='inner')
# Out:
#        name
# 0    hellof
# 1  masonsxu

# %%
pd.merge(df1, df2, how='left')
# Out:
#        name
# 0    hellof
# 1  masonsxu
# 2         a
# 3         b
# 4         c

# %%
pd.merge(df1, df2, how='right')
# Out:
#        name
# 0    hellof
# 1  masonsxu
# 2         A
# 3         B
# 4         C

# %%
pd.merge(df1, df2, how='outer')
# Out:
#        name
# 0    hellof
# 1  masonsxu
# 2         a
# 3         b
# 4         c
# 5         A
# 6         B
# 7         C

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

import pyecharts.options as opts
from pyecharts.globals import ThemeType

# %%
from pyecharts.charts import Pie

vote_result = pd.read_csv('data/vote_result.csv')

pie = (
    Pie(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add('领域名称', [list(z) for z in zip(vote_result['Areas_of_interest'].tolist(), vote_result['Votes'].tolist())],
         radius=[None, 150], tooltip_opts=opts.TooltipOpts(textstyle_opts=opts.TextStyleOpts(align='center'),
                                                          formatter='{a}'+'<br/>'+'{b}: {c} ({d}%)'))
    .set_global_opts(title_opts=opts.TitleOpts(title="数据可视化-用户感兴趣领域",
                                               subtitle="以下是读者的投票结果。\n读者对金融、医疗保健、市场3个领域最感兴趣", 
                                               pos_left='center'),
                     legend_opts=opts.LegendOpts(orient="vertical", pos_left="2%")
                    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter='{b}'))
)
pie.load_javascript()
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="50a4946f6b544f418eed5a72b8b23f56" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_50a4946f6b544f418eed5a72b8b23f56 = echarts.init(
#             document.getElementById('50a4946f6b544f418eed5a72b8b23f56'), 'dark', {renderer: 'canvas'});
#         var option_50a4946f6b544f418eed5a72b8b23f56 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u9886\u57df\u540d\u79f0",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91d1\u878d",
#                     "value": 172
#                 },
#                 {
#                     "name": "\u533b\u7597\u4fdd\u5065",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u5e02\u573a\u4e1a",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u96f6\u552e\u4e1a",
#                     "value": 101
#                 },
#                 {
#                     "name": "\u5236\u9020\u4e1a",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u53f8\u6cd5",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u5de5\u7a0b\u4e0e\u79d1\u5b66",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u4fdd\u9669\u4e1a",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 41
#                 }
#             ],
#             "radius": [
#                 null,
#                 150
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}"
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a}<br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "align": "center"
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91d1\u878d",
#                 "\u533b\u7597\u4fdd\u5065",
#                 "\u5e02\u573a\u4e1a",
#                 "\u96f6\u552e\u4e1a",
#                 "\u5236\u9020\u4e1a",
#                 "\u53f8\u6cd5",
#                 "\u5de5\u7a0b\u4e0e\u79d1\u5b66",
#                 "\u4fdd\u9669\u4e1a",
#                 "\u5176\u4ed6"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6570\u636e\u53ef\u89c6\u5316-\u7528\u6237\u611f\u5174\u8da3\u9886\u57df",
#             "subtext": "\u4ee5\u4e0b\u662f\u8bfb\u8005\u7684\u6295\u7968\u7ed3\u679c\u3002\n\u8bfb\u8005\u5bf9\u91d1\u878d\u3001\u533b\u7597\u4fdd\u5065\u3001\u5e02\u573a3\u4e2a\u9886\u57df\u6700\u611f\u5174\u8da3",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_50a4946f6b544f418eed5a72b8b23f56.setOption(option_50a4946f6b544f418eed5a72b8b23f56);
#     </script>
# </body>
# </html>

# %%
pie = (
    Pie(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add('领域名称', [list(z) for z in zip(vote_result['Areas_of_interest'].tolist(), vote_result['Votes'].tolist())],
         radius=[100, 150], tooltip_opts=opts.TooltipOpts(textstyle_opts=opts.TextStyleOpts(align='center'),
                                                          formatter='{a}'+'<br/>'+'{b}: {c} ({d}%)'))
    .set_global_opts(title_opts=opts.TitleOpts(title="数据可视化-用户感兴趣领域",
                                               subtitle="以下是读者的投票结果。\n读者对金融、医疗保健、市场3个领域最感兴趣", 
                                               pos_left='center'),
                     legend_opts=opts.LegendOpts(orient="vertical", pos_left="2%")
                    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter='{b}'))
)
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="46b8bf012450434e8f74a64b5edc0174" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_46b8bf012450434e8f74a64b5edc0174 = echarts.init(
#             document.getElementById('46b8bf012450434e8f74a64b5edc0174'), 'dark', {renderer: 'canvas'});
#         var option_46b8bf012450434e8f74a64b5edc0174 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u9886\u57df\u540d\u79f0",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91d1\u878d",
#                     "value": 172
#                 },
#                 {
#                     "name": "\u533b\u7597\u4fdd\u5065",
#                     "value": 136
#                 },
#                 {
#                     "name": "\u5e02\u573a\u4e1a",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u96f6\u552e\u4e1a",
#                     "value": 101
#                 },
#                 {
#                     "name": "\u5236\u9020\u4e1a",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u53f8\u6cd5",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u5de5\u7a0b\u4e0e\u79d1\u5b66",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u4fdd\u9669\u4e1a",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 41
#                 }
#             ],
#             "radius": [
#                 100,
#                 150
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}"
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "formatter": "{a}<br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "align": "center"
#                 },
#                 "borderWidth": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91d1\u878d",
#                 "\u533b\u7597\u4fdd\u5065",
#                 "\u5e02\u573a\u4e1a",
#                 "\u96f6\u552e\u4e1a",
#                 "\u5236\u9020\u4e1a",
#                 "\u53f8\u6cd5",
#                 "\u5de5\u7a0b\u4e0e\u79d1\u5b66",
#                 "\u4fdd\u9669\u4e1a",
#                 "\u5176\u4ed6"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6570\u636e\u53ef\u89c6\u5316-\u7528\u6237\u611f\u5174\u8da3\u9886\u57df",
#             "subtext": "\u4ee5\u4e0b\u662f\u8bfb\u8005\u7684\u6295\u7968\u7ed3\u679c\u3002\n\u8bfb\u8005\u5bf9\u91d1\u878d\u3001\u533b\u7597\u4fdd\u5065\u3001\u5e02\u573a3\u4e2a\u9886\u57df\u6700\u611f\u5174\u8da3",
#             "left": "center",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_46b8bf012450434e8f74a64b5edc0174.setOption(option_46b8bf012450434e8f74a64b5edc0174);
#     </script>
# </body>
# </html>

# %%
from pyecharts.charts import Bar

pre_approval_rate = pd.read_csv('data/presidential_approval_rate.csv')

bar = (
    Bar(init_opts = opts.InitOpts(theme = ThemeType.DARK))
    .add_xaxis(pre_approval_rate['political_issue'].tolist())
    .add_yaxis("支持", pre_approval_rate['support'].tolist(), stack="1", category_gap="50%")
    .add_yaxis("反对", pre_approval_rate['oppose'].tolist(), stack="1", category_gap="50%")
    .add_yaxis("不发表意见", pre_approval_rate['no_opinion'].tolist(), stack="1", category_gap="50%")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title = "柱状图数据堆叠示例"),
                    xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=30)))
)
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="edb5c0fa3d0b414f888cabd53d4ad813" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_edb5c0fa3d0b414f888cabd53d4ad813 = echarts.init(
#             document.getElementById('edb5c0fa3d0b414f888cabd53d4ad813'), 'dark', {renderer: 'canvas'});
#         var option_edb5c0fa3d0b414f888cabd53d4ad813 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u652f\u6301",
#             "data": [
#                 52,
#                 49,
#                 48,
#                 47,
#                 44,
#                 43,
#                 41,
#                 41,
#                 40,
#                 38,
#                 36,
#                 31,
#                 29
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u53cd\u5bf9",
#             "data": [
#                 38,
#                 40,
#                 45,
#                 42,
#                 48,
#                 51,
#                 53,
#                 54,
#                 57,
#                 59,
#                 57,
#                 64,
#                 62
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u4e0d\u53d1\u8868\u610f\u89c1",
#             "data": [
#                 10,
#                 11,
#                 7,
#                 11,
#                 8,
#                 6,
#                 6,
#                 5,
#                 3,
#                 3,
#                 7,
#                 5,
#                 9
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u652f\u6301",
#                 "\u53cd\u5bf9",
#                 "\u4e0d\u53d1\u8868\u610f\u89c1"
#             ],
#             "selected": {
#                 "\u652f\u6301": true,
#                 "\u53cd\u5bf9": true,
#                 "\u4e0d\u53d1\u8868\u610f\u89c1": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 30,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u79cd\u65cf\u95ee\u9898",
#                 "\u6559\u80b2",
#                 "\u6050\u6016\u6d3b\u52a8",
#                 "\u80fd\u6e90\u653f\u7b56",
#                 "\u5916\u4ea4\u4e8b\u52a1",
#                 "\u73af\u5883",
#                 "\u5b97\u6559\u653f\u7b56",
#                 "\u7a0e\u6536",
#                 "\u533b\u7597\u4fdd\u5065\u653f\u7b56",
#                 "\u7ecf\u6d4e",
#                 "\u5c31\u4e1a\u653f\u7b56",
#                 "\u8d38\u6613\u653f\u7b56",
#                 "\u5916\u6765\u79fb\u6c11"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67f1\u72b6\u56fe\u6570\u636e\u5806\u53e0\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_edb5c0fa3d0b414f888cabd53d4ad813.setOption(option_edb5c0fa3d0b414f888cabd53d4ad813);
#     </script>
# </body>
# </html>

# %%
list_support = ['支持', '反对', '不发表意见']

bar = Bar(init_opts = opts.InitOpts(theme = ThemeType.DARK))
bar.add_xaxis(list_support)
for i in range(pre_approval_rate.iloc[:,0].size):
    issue = pre_approval_rate.loc[i,'political_issue']
    bar.add_yaxis(issue, [int(x) for x in pre_approval_rate.loc[i,['support','oppose','no_opinion']]], 
                  stack="1", category_gap="50%")
bar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
bar.set_global_opts(title_opts=opts.TitleOpts(title = "柱状图数据堆叠示例", pos_left='center'),
                    legend_opts=opts.LegendOpts(orient="vertical", pos_right="2%"))
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="747bc9befb744c278469580987a576e6" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_747bc9befb744c278469580987a576e6 = echarts.init(
#             document.getElementById('747bc9befb744c278469580987a576e6'), 'dark', {renderer: 'canvas'});
#         var option_747bc9befb744c278469580987a576e6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u79cd\u65cf\u95ee\u9898",
#             "data": [
#                 52,
#                 38,
#                 10
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6559\u80b2",
#             "data": [
#                 49,
#                 40,
#                 11
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6050\u6016\u6d3b\u52a8",
#             "data": [
#                 48,
#                 45,
#                 7
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u80fd\u6e90\u653f\u7b56",
#             "data": [
#                 47,
#                 42,
#                 11
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5916\u4ea4\u4e8b\u52a1",
#             "data": [
#                 44,
#                 48,
#                 8
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u73af\u5883",
#             "data": [
#                 43,
#                 51,
#                 6
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5b97\u6559\u653f\u7b56",
#             "data": [
#                 41,
#                 53,
#                 6
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7a0e\u6536",
#             "data": [
#                 41,
#                 54,
#                 5
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u533b\u7597\u4fdd\u5065\u653f\u7b56",
#             "data": [
#                 40,
#                 57,
#                 3
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7ecf\u6d4e",
#             "data": [
#                 38,
#                 59,
#                 3
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5c31\u4e1a\u653f\u7b56",
#             "data": [
#                 36,
#                 57,
#                 7
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u8d38\u6613\u653f\u7b56",
#             "data": [
#                 31,
#                 64,
#                 5
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5916\u6765\u79fb\u6c11",
#             "data": [
#                 29,
#                 62,
#                 9
#             ],
#             "stack": "1",
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u79cd\u65cf\u95ee\u98

# %%
import os
import json
import codecs
from pyecharts.charts import Tree
with codecs.open(os.path.join('data', 'GDP_data.json'), 'r', encoding='utf8') as f:
    j = json.load(f)
data = [j]
tree = (
    Tree(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add("", data)
    .set_global_opts(title_opts=opts.TitleOpts(title="树图"))
)
tree.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="c57065ee6812448ba6d9bac5705c7f7a" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_c57065ee6812448ba6d9bac5705c7f7a = echarts.init(
#             document.getElementById('c57065ee6812448ba6d9bac5705c7f7a'), 'dark', {renderer: 'canvas'});
#         var option_c57065ee6812448ba6d9bac5705c7f7a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "tree",
#             "data": [
#                 {
#                     "name": "World GDP",
#                     "children": [
#                         {
#                             "value": 0.3183,
#                             "name": "\u4e9a\u6d32",
#                             "children": [
#                                 {
#                                     "value": 0.1503,
#                                     "name": "\u4e2d\u56fd"
#                                 },
#                                 {
#                                     "value": 0.061,
#                                     "name": "\u65e5\u672c"
#                                 },
#                                 {
#                                     "value": 0.0327,
#                                     "name": "\u5370\u5ea6"
#                                 },
#                                 {
#                                     "value": 0.0192,
#                                     "name": "\u97e9\u56fd"
#                                 },
#                                 {
#                                     "value": 0.0127,
#                                     "name": "\u5370\u5c3c"
#                                 },
#                                 {
#                                     "value": 0.0106,
#                                     "name": "\u571f\u8033\u5176"
#                                 },
#                                 {
#                                     "value": 0.0086,
#                                     "name": "\u6c99\u7279"
#                                 },
#                                 {
#                                     "value": 0.0057,
#                                     "name": "\u6cf0\u56fd"
#                                 },
#                                 {
#                                     "value": 0.0054,
#                                     "name": "\u4f0a\u6717"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 0.2072,
#                             "name": "\u6b27\u6d32",
#                             "children": [
#                                 {
#                                     "value": 0.0461,
#                                     "name": "\u5fb7\u56fd"
#                                 },
#                                 {
#                                     "value": 0.0328,
#                                     "name": "\u82f1\u56fd"
#                                 },
#                                 {
#                                     "value": 0.0323,
#                                     "name": "\u6cd5\u56fd"
#                                 },
#                                 {
#                                     "value": 0.0242,
#                                     "name": "\u610f\u5927\u5229"
#                                 },
#                                 {
#                                     "value": 0.0191,
#                                     "name": "\u4fc4\u7f57\u65af"
#                                 },
#                                 {
#                                     "value": 0.0164,
#                                     "name": "\u897f\u73ed\u7259"
#                                 },
#                                 {
#                                     "value": 0.0103,
#                                     "name": "\u8377\u5170"
#                                 },
#                                 {
#                                     "value": 0.0085,
#                                     "name": "\u745e\u58eb"
#                                 },
#                                 {
#                                     "value": 0.0067,
#                                     "name": "\u745e\u5178"
#                                 },
#                                 {
#                                     "value": 0.0066,
#                                     "name": "\u6ce2\u5170"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 0.0337,
#                             "name": "\u5357\u7f8e\u6d32",
#                             "children": [
#                                 {
#                                     "value": 0.0257,
#                                     "name": "\u5df4\u897f"
#                                 },
#                                 {
#                                     "value": 0.008,
#                                     "name": "\u963f\u6839\u5ef7"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 0.0173,
#                             "name": "\u5927\u6d0b\u6d32",
#                             "children": [
#                                 {
#                                     "value": 0.0173,
#                                     "name": "\u6fb3\u5927\u5229\u4e9a"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 0.2777,
#                             "name": "\u5317\u7f8e\u6d32",
#                             "children": [
#                                 {
#                                     "value": 0.2426,
#                                     "name": "\u7f8e\u56fd"
#                                 },
#                                 {
#                                     "value": 0.0207,
#                                     "name": "\u52a0\u62ff\u5927"
#                                 },
#                                 {
#                                     "value": 0.0144,
#                                     "name": "\u58a8\u897f\u54e5"
#                                 }
#                             ]
#                         },
#                         {
#                             "value": 0.1449,
#                             "name": "\u5176\u4ed6\u56fd\u5bb6"
#                         }
#                     ]
#                 }
#             ],
#             "symbol": "emptyCircle",
#             "symbolSize": 7,
#             "roam": false,
#             "expandAndCollapse": true,
#             "layout": "orthogonal",
#             "orient": "LR",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "leaves": {
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6811\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_c57065ee6812448ba6d9bac5705c7f7a.setOption(option_c57065ee681

# %%
from pyecharts.charts import TreeMap
with open(os.path.join('data', 'GDP_data_1.json'), 'r', encoding='utf8') as f:
    data = json.load(f)
treemap = (
    TreeMap(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add("演示数据", data)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=True, position='inside'))
    .set_global_opts(title_opts=opts.TitleOpts(title="矩形树图示例"))
)
treemap.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b1db4ee1e1544f3cb2277cf5bd6f5b11" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_b1db4ee1e1544f3cb2277cf5bd6f5b11 = echarts.init(
#             document.getElementById('b1db4ee1e1544f3cb2277cf5bd6f5b11'), 'dark', {renderer: 'canvas'});
#         var option_b1db4ee1e1544f3cb2277cf5bd6f5b11 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "treemap",
#             "name": "\u6f14\u793a\u6570\u636e",
#             "data": [
#                 {
#                     "value": 0.3183,
#                     "name": "\u4e9a\u6d32",
#                     "children": [
#                         {
#                             "value": 0.1503,
#                             "name": "\u4e2d\u56fd"
#                         },
#                         {
#                             "value": 0.061,
#                             "name": "\u65e5\u672c"
#                         },
#                         {
#                             "value": 0.0327,
#                             "name": "\u5370\u5ea6"
#                         },
#                         {
#                             "value": 0.0192,
#                             "name": "\u97e9\u56fd"
#                         },
#                         {
#                             "value": 0.0127,
#                             "name": "\u5370\u5c3c"
#                         },
#                         {
#                             "value": 0.0106,
#                             "name": "\u571f\u8033\u5176"
#                         },
#                         {
#                             "value": 0.0086,
#                             "name": "\u6c99\u7279"
#                         },
#                         {
#                             "value": 0.0057,
#                             "name": "\u6cf0\u56fd"
#                         },
#                         {
#                             "value": 0.0054,
#                             "name": "\u4f0a\u6717"
#                         }
#                     ]
#                 },
#                 {
#                     "value": 0.2072,
#                     "name": "\u6b27\u6d32",
#                     "children": [
#                         {
#                             "value": 0.0461,
#                             "name": "\u5fb7\u56fd"
#                         },
#                         {
#                             "value": 0.0328,
#                             "name": "\u82f1\u56fd"
#                         },
#                         {
#                             "value": 0.0323,
#                             "name": "\u6cd5\u56fd"
#                         },
#                         {
#                             "value": 0.0242,
#                             "name": "\u610f\u5927\u5229"
#                         },
#                         {
#                             "value": 0.0191,
#                             "name": "\u4fc4\u7f57\u65af"
#                         },
#                         {
#                             "value": 0.0164,
#                             "name": "\u897f\u73ed\u7259"
#                         },
#                         {
#                             "value": 0.0103,
#                             "name": "\u8377\u5170"
#                         },
#                         {
#                             "value": 0.0085,
#                             "name": "\u745e\u58eb"
#                         },
#                         {
#                             "value": 0.0067,
#                             "name": "\u745e\u5178"
#                         },
#                         {
#                             "value": 0.0066,
#                             "name": "\u6ce2\u5170"
#                         }
#                     ]
#                 },
#                 {
#                     "value": 0.0337,
#                     "name": "\u5357\u7f8e\u6d32",
#                     "children": [
#                         {
#                             "value": 0.0257,
#                             "name": "\u5df4\u897f"
#                         },
#                         {
#                             "value": 0.008,
#                             "name": "\u963f\u6839\u5ef7"
#                         }
#                     ]
#                 },
#                 {
#                     "value": 0.0173,
#                     "name": "\u5927\u6d0b\u6d32",
#                     "children": [
#                         {
#                             "value": 0.0173,
#                             "name": "\u6fb3\u5927\u5229\u4e9a"
#                         }
#                     ]
#                 },
#                 {
#                     "value": 0.2777,
#                     "name": "\u5317\u7f8e\u6d32",
#                     "children": [
#                         {
#                             "value": 0.2426,
#                             "name": "\u7f8e\u56fd"
#                         },
#                         {
#                             "value": 0.0207,
#                             "name": "\u52a0\u62ff\u5927"
#                         },
#                         {
#                             "value": 0.0144,
#                             "name": "\u58a8\u897f\u54e5"
#                         }
#                     ]
#                 },
#                 {
#                     "value": 0.1449,
#                     "name": "\u5176\u4ed6\u56fd\u5bb6"
#                 }
#             ],
#             "width": "80%",
#             "height": "80%",
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "upperlabel": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "drillDownIcon": "\u25b6",
#             "roam": true,
#             "nodeClick": "zoomToNode",
#             "zoomToNodeRatio": 0.1024,
#             "colorMappingBy": "index",
#             "visibleMin": 10,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6f14\u793a\u6570\u636e"
#             ],
#             "selected": {
#                 "\u6f14\u793a\u6570\u636e": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u77e9\u5f62\u6811\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_b1db4ee1e1544f3cb2277cf5bd6f5b11.setOption(option_b1db4ee1e1544f3cb2277cf5bd6f5b11);
#     </script>
# </body>
# </html>

# %%
from pyecharts.charts import Line

year_population_age = pd.read_csv('data/us_population_by_age.csv')

line3 = (
    Line(init_opts=opts.InitOpts(theme=ThemeType.DARK))
    .add_xaxis(year_population_age['year'].tolist())
    .add_yaxis('5岁以下', year_population_age['year_under5'].tolist(), color='red',                
               stack='1')
    .add_yaxis('5岁至19岁', year_population_age['year5_19'].tolist(), color='blue', 
               stack='1')
    .add_yaxis('20至44岁', year_population_age['year20_44'].tolist(), color='green', 
               stack='1')
    .add_yaxis('45至64岁', year_population_age['year45_64'].tolist(), color='yellow', 
              stack='1')
    .add_yaxis('65岁以上', year_population_age['year65above'].tolist(), color='orange', 
               stack='1')
    .set_series_opts(areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
                     label_opts=opts.LabelOpts(is_show=False),
                     markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_='max'),
                                                             opts.MarkPointItem(type_='min')],
                                                       symbol='pin'))
    .set_global_opts(title_opts=opts.TitleOpts(title='面积折线图'))
)
line3.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="b9d126d8348e4bafb3446c02be790774" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_b9d126d8348e4bafb3446c02be790774 = echarts.init(
#             document.getElementById('b9d126d8348e4bafb3446c02be790774'), 'dark', {renderer: 'canvas'});
#         var option_b9d126d8348e4bafb3446c02be790774 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "name": "5\u5c81\u4ee5\u4e0b",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "1",
#             "data": [
#                 [
#                     "1860\u5e74",
#                     15.4
#                 ],
#                 [
#                     "1870\u5e74",
#                     14.3
#                 ],
#                 [
#                     "1880\u5e74",
#                     13.8
#                 ],
#                 [
#                     "1890\u5e74",
#                     12.2
#                 ],
#                 [
#                     "1900\u5e74",
#                     12.1
#                 ],
#                 [
#                     "1910\u5e74",
#                     11.6
#                 ],
#                 [
#                     "1920\u5e74",
#                     10.9
#                 ],
#                 [
#                     "1930\u5e74",
#                     9.3
#                 ],
#                 [
#                     "1940\u5e74",
#                     8.0
#                 ],
#                 [
#                     "1950\u5e74",
#                     10.7
#                 ],
#                 [
#                     "1960\u5e74",
#                     11.3
#                 ],
#                 [
#                     "1970\u5e74",
#                     8.4
#                 ],
#                 [
#                     "1980\u5e74",
#                     7.2
#                 ],
#                 [
#                     "1990\u5e74",
#                     7.6
#                 ],
#                 [
#                     "2000\u5e74",
#                     6.8
#                 ],
#                 [
#                     "2005\u5e74",
#                     6.8
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "markPoint": {
#                 "symbol": "pin",
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "max"
#                     },
#                     {
#                         "type": "min"
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "5\u5c81\u81f319\u5c81",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "1",
#             "data": [
#                 [
#                     "1860\u5e74",
#                     35.8
#                 ],
#                 [
#                     "1870\u5e74",
#                     35.4
#                 ],
#                 [
#                     "1880\u5e74",
#                     34.3
#                 ],
#                 [
#                     "1890\u5e74",
#                     33.9
#                 ],
#                 [
#                     "1900\u5e74",
#                     32.3
#                 ],
#                 [
#                     "1910\u5e74",
#                     30.4
#                 ],
#                 [
#                     "1920\u5e74",
#                     29.8
#                 ],
#                 [
#                     "1930\u5e74",
#                     29.5
#                 ],
#                 [
#                     "1940\u5e74",
#                     26.4
#                 ],
#                 [
#                     "1950\u5e74",
#                     23.2
#                 ],
#                 [
#                     "1960\u5e74",
#                     27.1
#                 ],
#                 [
#                     "1970\u5e74",
#                     29.5
#                 ],
#                 [
#                     "1980\u5e74",
#                     24.8
#                 ],
#                 [
#                     "1990\u5e74",
#                     21.3
#                 ],
#                 [
#                     "2000\u5e74",
#                     21.8
#                 ],
#                 [
#                     "2005\u5e74",
#                     20.7
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "markPoint": {
#                 "symbol": "pin",
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "type": "max"
#                     },
#                     {
#                         "type": "min"
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "20\u81f344\u5c81",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "stack": "1",
#             "data": [
#                 [
#                     "1860\u5e74",
#                     35.7
#                 ],
#                 [
#                     "1870\u5e74",
#                     35.4
#                 ],
#                 [
#                     "1880\u5e74",
#                     35.9
#                 ],
#                 [
#                     "1890\u5e74",
#                     36.9
#                 ],
#                 [
#                     "1900\u5e74",
#                     37.7
#                 ],
#                 [
#                     "1910\u5e74",
#                     39.0
#                 ],
#                 [
#                     "1920\u5e74",
#                     38.4
#                 ],
#                 [
#                     "1930\u5e74",
#                     38.3
#                 ],
#                 [
#                     "1940\u5e74",
#                     38.9
#                 ],
#                 [
#                     "1950\u5e74",
#                     37.6
#                 ],
#                 [
#                     "1960\u5e74",
#                     32.2
#                 ],
#                 [
